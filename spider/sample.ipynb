# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
from urllib.parse import urljoin
from elasticsearch import Elasticsearch
from datetime import datetime
# real-----------------------------------------

class Spider:
    def __init__(self, start_url, max_pages):
        self.start_url = start_url
        self.max_pages = max_pages
        self.visited_urls = set()# 记录已访问的url
        self.url_map = {}  # 记录url和page_id的映射关系
        self.to_visit_urls = deque([start_url])
        self.page_count = 0
        self.page_id_counter = 1  # 用于分配唯一的 page_id
        # 初始化 Elasticsearch 客户端
        self.es = Elasticsearch("http://localhost:9200")
        # 创建网页信息索引
        self.create_index('web_pages', {
            "mappings": {
                "properties": {
                    "page_id": {"type": "integer"},
                    "url": {"type": "keyword"},
                    "title": {"type": "text"},
                    "content": {"type": "text"},
                    "last_modify_time": {"type": "date"},
                    "size": {"type": "integer"}
                }
            }
        })
        # 创建网页结构索引(parent, child)
        self.create_index('web_page_structure', {
            "mappings": {
                "properties": {
                    "parent_page_id": {"type": "integer"},
                    "child_page_id": {"type": "integer"}
                }
            }
        })
        # 创建反向网页结构索引（子 -> 父）
        self.create_index('reverse_web_page_structure', {
            "mappings": {
                "properties": {
                    "child_page_id": {"type": "integer"},
                    "parent_page_id": {"type": "integer"}
                }
            }
        })

    def create_index(self, index_name, mapping):
        # 检查索引是否存在
        if self.es.indices.exists(index=index_name):
            # 如果存在，则删除该索引
            self.es.indices.delete(index=index_name)
            print(f"索引 {index_name} 已删除")
        # 创建新的索引
        self.es.indices.create(index=index_name, body=mapping)
        print(f"索引 {index_name} 创建成功")

    def fetch_page_links(self, url):
        try:
            response = requests.get(url)
            if response.status_code == 200:
                # 检查 HTTP 头中的 Last-Modified 字段
                last_modified = response.headers.get('Last-Modified')
                if last_modified:
                    last_modify_time = datetime.strptime(last_modified, '%a, %d %b %Y %H:%M:%S %Z')
                else:
                    last_modify_time = datetime.now()
                soup = BeautifulSoup(response.text, 'html.parser')
                title = soup.title.string if soup.title else ''
                content =soup.body.get_text().replace('\n', '').replace('\r', '')
                size=response.raw._fp_bytes_read if response.raw._fp_bytes_read else 0

                # 没访问过且没分配过id
                if url not in self.url_map:
                    page_id = self.page_id_counter
                    self.page_id_counter += 1
                    self.url_map[url] = page_id
                # 没访问过但分配过id
                else:
                    page_id = self.url_map[url]
                # 存储网页信息到 Elasticsearch
                self.store_page_info(page_id, url, title, content, last_modify_time,size)

                links = [link.get('href') for link in soup.find_all('a', href=True)]
                return page_id, links
            return None, []
        except requests.RequestException as e:
            print(f"Failed to fetch {url}: {e}")
            return None, []

    def store_page_info(self, page_id, url, title, content, last_modify_time,size):
        doc = {
            "page_id": page_id,
            "url": url,
            "title": title,
            "content": content,
            "last_modify_time": last_modify_time,
            "size": size
        }
        self.es.index(index='web_pages', id=page_id, body=doc)

    def store_page_structure(self, parent_page_id, child_page_id):
        doc = {
            "parent_page_id": parent_page_id,
            "child_page_id": child_page_id
        }
        self.es.index(index='web_page_structure', body=doc)
        # 存储反向网页结构
        reverse_doc = {
            "child_page_id": child_page_id,
            "parent_page_id": parent_page_id
        }
        self.es.index(index='reverse_web_page_structure', body=reverse_doc)

    def crawl(self):
        while self.to_visit_urls and self.page_count < self.max_pages:
            url = self.to_visit_urls.popleft()
            if url in self.visited_urls:
                continue
            print(f"Crawling: {url}")
            self.visited_urls.add(url)
            self.page_count += 1
            parent_page_id, links = self.fetch_page_links(url)#肯定没访问过
            if parent_page_id:
                for link in links:
                    new_full_url = urljoin(url, link)
                    
                    # 没分配过id(没访问过   )
                    if new_full_url not in self.url_map:
                        child_page_id = self.page_id_counter
                        self.page_id_counter += 1
                        self.url_map[new_full_url] = child_page_id
                        self.to_visit_urls.append(new_full_url)
                    # 已分配过id(没访问过)
                    elif new_full_url in self.url_map and new_full_url not in self.visited_urls:
                        child_page_id = self.url_map[new_full_url]
                        self.to_visit_urls.append(new_full_url)
                    # 已访问过(已分配过id)
                    elif new_full_url in self.visited_urls:
                        child_page_id = self.url_map[new_full_url]
                    
                    self.store_page_structure(parent_page_id, child_page_id)
    
    def view_web_pages_data(self):
        """查看 web_pages 索引中的数据"""
        query = {
            "query": {
                "match_all": {}
            },
            "size": 1000
        }
        result = self.es.search(index='web_pages', body=query)
        for hit in result['hits']['hits']:
            print(hit['_source'])

    def view_web_page_structure_data(self):
        """查看 web_page_structure 索引中的数据"""
        query = {
            "query": {
                "match_all": {}
            },
            "size": 1000
        }
        result = self.es.search(index='web_page_structure', body=query)
        for hit in result['hits']['hits']:
            print(hit['_source'])
            
    def view_reverse_web_page_structure_data(self):
        """查看 reverse_web_page_structure 索引中的数据"""
        query = {
            "query": {
                "match_all": {}
            },
            "size": 1000
        }
        result = self.es.search(index='reverse_web_page_structure', body=query)
        for hit in result['hits']['hits']:
            print(hit['_source'])


if __name__ == "__main__":
    start_url = 'https://www.cse.ust.hk/~kwtleung/COMP4321/testpage.htm'
    max_pages = 10
    spider = Spider(start_url, max_pages)
    spider.crawl()
# Out:
# 索引 web_pages 已删除
# 索引 web_pages 创建成功
# 索引 web_page_structure 已删除
# 索引 web_page_structure 创建成功
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33228\96949196.py:59: DeprecationWarning: The 'body' parameter is deprecated for the 'create' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   self.es.indices.create(index=index_name, body=mapping)
# 索引 reverse_web_page_structure 已删除
# 索引 reverse_web_page_structure 创建成功
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/testpage.htm
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33228\96949196.py:104: DeprecationWarning: The 'body' parameter is deprecated for the 'index' API and will be removed in a future version. Instead use the 'document' parameter. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   self.es.index(index='web_pages', id=page_id, body=doc)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33228\96949196.py:111: DeprecationWarning: The 'body' parameter is deprecated for the 'index' API and will be removed in a future version. Instead use the 'document' parameter. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   self.es.index(index='web_page_structure', body=doc)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33228\96949196.py:117: DeprecationWarning: The 'body' parameter is deprecated for the 'index' API and will be removed in a future version. Instead use the 'document' parameter. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   self.es.index(index='reverse_web_page_structure', body=reverse_doc)
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/ust_cse.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/news.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/books.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/Movie.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/ust_cse/PG.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/ust_cse/UG.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/news/bbc.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/news/cnn.htm
# Crawling: https://www.cse.ust.hk/~kwtleung/COMP4321/books/book1.htm

# %%
spider.page_count
# Out:
# 10

# %%
spider.view_web_pages_data()
# Out:
# {'page_id': 1, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/testpage.htm', 'title': 'Test page', 'content': 'This is the Test page for a crawlerBefore getting the Admission ofCSE department of HKUST, You should read through these international news and thesebooks.Here is my Movie List (New)', 'last_modify_time': '2023-05-16T05:03:16', 'size': 603}
# {'page_id': 2, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/ust_cse.htm', 'title': 'CSE department of HKUST', 'content': 'CSE department of HKUSTPG AdmissionUG AdmissionBack to main', 'last_modify_time': '2023-05-16T05:03:16', 'size': 392}
# {'page_id': 3, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/news.htm', 'title': 'News', 'content': 'NewsBBC newsCNN newsBack to main', 'last_modify_time': '2023-05-16T05:03:16', 'size': 384}
# {'page_id': 4, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/books.htm', 'title': 'books', 'content': 'Books and articles to readAutomated Keyword Classification for Information RetrievalGeneration and Uses of Machine-Readable Data Bases A Note on the Pseudo-Mathematics of Relevance Back to main', 'last_modify_time': '2023-05-16T05:03:16', 'size': 601}
# {'page_id': 5, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/Movie.htm', 'title': 'Movie Index Page', 'content': "My movie listBack to mainDinosaur Planet (2003)Isle of Man TT 2004 Review (2004)Character (1997)Paula Abdul's Get Up and Dance (1994)The Rise and Fall of ECW (2004)Sick (1997)8 Man (1992)What the #$*! Do We Know!? (2004)Class of Nuke 'Em High 2 (1991)Fighter (2001)Full Frame: Documentary Shorts (1999)My Favorite Brunette (1947)Lord of the Rings: The Return of the King: Extended Edition: Bonus Material (2003)Nature: Antarctica (1982)Neil Diamond: Greatest Hits Live (1988)Screamers (1996)7 Seconds (2005)Immortal Beloved (1994)By Dawn's Early Light (2000)Seeta Aur Geeta (1972)Strange Relations (2002)Chump Change (2000)Clifford: Clifford Saves the Day! / Clifford's Fluffiest Friend Cleo (2001)My Bloody Valentine (1981)Inspector Morse 31: Death Is Now My Neighbour (1997)Never Die Alone (2004)Sesame Street: Elmo's World: The Street We Live On (1962)Lilo and Stitch (2002)Boycott (2001)Something's Gotta Give (2003)Classic Albums: Meat Loaf: Bat Out of Hell (1999)ABC Primetime: Mel Gibson's The Passion of the Christ (2004)Aqua Teen Hunger Force: Vol. 1 (2000)Ashtanga Yoga: Beginner's Practice with Nicki Doane (2003)Ferngully 2: The Magical Rescue (2000)Lady Chatterley (1992)Zatoichi's Conspiracy (1973)Daydream Obsession (2003)Love Reinvented (2000)Pitcher and the Pin-Up (2004)Horror Vision (2000)Searching for Paradise (2002)Silent Service (2000)Spitfire Grill (1996)The Love Letter (1999)Rudolph the Red-Nosed Reindeer (1964)The Bad and the Beautiful (1952)Justice League (2001)Devo: The Complete Truth About De-evolution (2003)A Yank in the R.A.F. (1941)Jonah: A VeggieTales Movie: Bonus Material (2002)The Weather Underground (2002)The Bonesetter (2003)We're Not Married (1952)Jade (1995)Carandiru (2004)Richard III (1995)Dragonheart (1996)Sex and the Beauties (2003)The Libertine (1969)Ricky Martin: One Night Only (1999)Ken Burns' America: Empire of the Air (1991)Crash Dive (1943)Outside the Law (2001)Lost in the Pershing Point Hotel (2000)Barbarian Queen 2 (1989)Vampire Journals (1997)Invader Zim (2004)WWE: Armageddon 2003 (2003)Tai Chi: The 24 Forms (1999)Maya Lin: A Strong Clear Vision (1995)At Home Among Strangers (1974)Davy Crockett: 50th Anniversary Double Feature (1954)6ixtynin9 (1999)Grind (1997)I Love Lucy: Season 2 (1952)Congo (1995)Jingle All the Way (1996)The Killing (1956)Winter Kills (1979)Antarctica: IMAX (1991)The Frogmen (1951)Silkwood (1983)The Powerpuff Girls Movie (2002)Elfen Lied (2005)Iron Monkey 2 (1996)Louder Than Bombs (2002)Record of Lodoss War: Chronicles of the Heroic Knight (1998)Chain of Command (2000)The Lemon Drop Kid (1951)WWE: Royal Rumble 2005 (2005)ECW: Cyberslam '99 (2002)They Came Back (2004)G3: Live in Concert (2000)Dona Herlinda and Her Son (1985)Inside the Space Station (2000)Mostly Martha (2002)The Battle of Algiers: Bonus Material (1965)A Fishy Story (1989)Sam the Iron Bridge (1993)Complete Shamanic Princess (1997)Notre Musique (2004)Sanford and Son: Season 6 (1976)The Great Race (1965)Obsessed (2002)Stevie Ray Vaughan and Double Trouble: Live at Montreux 1982 and 1985 (2004)Magnolia: Bonus Material (2000)Spartan (2004)No Way Back (1996)Scandal (1989)Duplex (Widescreen) (2003)The Eye of Vichy (1993)Bruce Lee: A Warrior's Journey (2000)Dominion Tank Police Part 1 and 2 (1989)Lord Peter Wimsey: Murder Must Advertise (1973)Bear Cub (2004)Silk Stockings (1957)Rambo: First Blood Part II (1985)Travel the World by Train: Africa (1999)Plain Dirty (2004)Beyonce: Live at Wembley (2003)Cube 2: Hypercube (2002)Chain of Fools (2000)Cold Blooded (2000)Nighthawks (1981)Vampire Effect (aka Twins Effect) (2003)Fatal Beauty (1987)Mr. Vampire (1985)Darkwolf (2003)Drowning on Dry Land (1999)Arachnid (2002)Lucio Fulci: The Beyond (1981)Viva La Bam: Season 1 (2003)Spirit Lost (1996)GTO: Great Teacher Onizuka: Set 2 (1998)Cat and the Canary (1927)Naked Lies (1998)Star Trek: Voyager: Season 1 (1995)Allergie ...
# {'page_id': 6, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/ust_cse/PG.htm', 'title': 'PG', 'content': "PG ProgramApplicants for admission to the postgraduate programs are required to have\xa0 completed, by the time they enter HKUST, a bachelor's degree in computer science or a related science or engineering field. Students admitted to a postgraduate program must demonstrate competence in the following core computer science areas: \xa0 Computer Organization \tPrinciples of Programming Languages \tPrinciples of Systems Software\xa0 (Operating Systems) \tDesign and Analysis of Algorithms In addition, students admitted into the PhD program must demonstrate competence in: Theory of Computation Competence in these areas is appraised during the admission process. A student whose formal computer science background is deemed inadequate in any of the above areas may be admitted on a provisional basis and will be required to take remedial courses prescribed by the Postgraduate Studies Committee and obtain a grade of at least B in these courses. Such additional requirements will be stipulated in the individual offer of admission. Deficiencies in any core computer science area can be made up concurrently with postgraduate work. Applicants are required to submit: \xa0 officially certified academic transcripts of undergraduate studies (and \tpostgraduate studies, if any); \tresults of the computer science subject Graduate Record (GRE) (required \tfor PhD applicants only; may be taken and submitted in the year after \tadmission); \tresults of an English proficiency test (see below); \ttwo letters of recommendation: a one-page statement of plan for the \tpostgraduate study; and \ta completed application form for postgraduate admission. For admission into the MSc and MPhil programs, results of standard examinations, such as the computer science subject Graduate Record Examination (GRE), may be helpful in determining suitability for admission and should be submitted as supplementary information, if available. All students admitted into a postgraduate program must demonstrate sufficient competence in English. Students whose previous degrees are from an institution where the primary language of instruction is other than English should submit the results of an English proficiency test (such as TOEFL) together with their application. The English proficiency test must have been taken within two years of the time of application. Notwithstanding the above, the Department may require newly admitted students to undergo language proficiency assessment and, if deemed necessary, to take English language enhancement courses. Admission to the Department's postgraduate programs will be based on the applicant's academic record as well as the research needs of the Department. ", 'last_modify_time': '2023-05-16T05:03:46', 'size': 3267}
# {'page_id': 7, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/ust_cse/UG.htm', 'title': 'UG', 'content': 'Program InformationThe Department of Computer Science at HKUST offers two degree programs for students who are interested in learning about computing and information technology:\xa01. COMP: BEng in Computer ScienceThis is our general undergraduate program that provides broad education \tin all areas of Computer Science.\xa02. CSIE: BEng in Computer Science (Information Engineering)This is a specialized undergraduate degree program focusing on the areas \tof multimedia computing and computer networking.While other Information Engineering programs in Hong Kong are closer to Electrical and Electronic Engineering, our CSIE program is unique in its emphasis on software. In fact, the CSIE program also satisfies all the general requirements of a typical Computer Science program. It has been carefully designed with the specific needs of Hong Kong in mind.\xa0Besides, the Department, jointly with the Department of Electrical and Electronic Engineering, also offers the BEng in Computer Engineering.\xa0\u3000A Spectrum of IT-Related ProgramsThe programs offered by our Department and the Department of Electrical and Electronic Engineering can be best viewed as the following spectrum:Software<----------------------->HardwareCOMP\xa0\xa0\xa0 CSIE\xa0\xa0\xa0 CPEG\xa0\xa0\xa0 EEIC\xa0\xa0\xa0 ELECGenerally speaking, the emphasis shifts from "soft" to "hard" as we move across the spectrum. The different programs suit different student interests and job market demands.\xa0\u3000Other OpportunitiesBesides the regular study programs, Computer Science students at HKUST also enjoy a number of other opportunities, including the following:\xa0Overseas exchange program:One-year full-time overseas study by paying only HKUST\'s tuition fee\xa0 \tWork-study program:One-year full-time work outside HKUST after two years of study \tIndustrial training:Training modules during winter and summer breaks on specific practical \tskills\xa0 \tEnglish training:Intensive training in written and conversational English, including \tpresentation skills \tFinal year projects:One year project in an area of specialization under the guidance of \tfaculty advisors\xa0 \tStudent tutors:Second and third year student helpers providing help to students in \tfirst-year courses \u3000Our GraduatesAbout 20% of our graduates choose to pursue postgraduate study immediately after graduation. While many of them stayed in HKUST for MPhil (Master of Philosophy) study, some went abroad to study at top universities, including Stanford University, University of Southern California, University of Toronto, University of Texas at Austin, and University of Illinois at Urbana-Champaign.\xa0Those who choose to work found excellent jobs. While graduates from related disciplines also look for computing related jobs, Computer Science graduates clearly have great advantages after completing a comprehensive program that provides solid training in fundamentals and many emerging areas of IT and computing.\u3000InquiriesStudents who need advice or assistance on application procedures, choice of programs, entrance requirements or other related matters are welcome to contact us:\xa0\u3000', 'last_modify_time': '2023-05-16T05:03:46', 'size': 4070}
# {'page_id': 8, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/news/bbc.htm', 'title': 'BBC news', 'content': 'BBC newsFifth nest for rare birds projectMP urges BT Goonhilly commitmentWest Ham 2-1 BlackburnBack to News', 'last_modify_time': '2023-05-16T05:03:44', 'size': 499}
# {'page_id': 9, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/news/cnn.htm', 'title': 'CNN news', 'content': "CNN newsSauerkraut Capital is sweet on accordionsWarming 'may cause economic chaos'Back to News", 'last_modify_time': '2023-05-16T05:03:44', 'size': 448}
# {'page_id': 10, 'url': 'https://www.cse.ust.hk/~kwtleung/COMP4321/books/book1.htm', 'title': 'book1', 'content': 'Automated Keyword Classification for Information Retrieval This book is primarily a research monograph, in which the discussion of the main topics has been broadened so that they are related to their surrounding context in information retrieval as a whole; it is not a textbook, and no attempt has therefore been made to justify the choice of topic, or account for the use of certain concepts, or to provide an elementary description of either. For instance in Chapter 1, it is assumed that the reader is familiar with the idea of using keywords in information retrieval: I have not considered the relation between this kind of retrieval device and a controlled thesaurus or descriptor set, or that between the use of simple class lists as document descriptions and the use of descriptions with a syntactic structure, for example. Equally, in Chapter 2, I have made use of recall/precision ratios as a means of characterising retrieval performance, without justification or argument; but this does not mean that I am unaware of the difficulties of doing this, or of the attention which has been devoted to, and controversy which has raged round, this subject; it is simply that from the point of view of my main purpose it is reasonable to use these ratios. Back to Books', 'last_modify_time': '2023-05-16T05:03:16', 'size': 1617}
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33228\96949196.py:156: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   result = self.es.search(index='web_pages', body=query)

# %%
spider.view_web_page_structure_data()
# Out:
# {'parent_page_id': 1, 'child_page_id': 2}
# {'parent_page_id': 1, 'child_page_id': 3}
# {'parent_page_id': 1, 'child_page_id': 4}
# {'parent_page_id': 1, 'child_page_id': 5}
# {'parent_page_id': 2, 'child_page_id': 6}
# {'parent_page_id': 2, 'child_page_id': 7}
# {'parent_page_id': 2, 'child_page_id': 1}
# {'parent_page_id': 3, 'child_page_id': 8}
# {'parent_page_id': 3, 'child_page_id': 9}
# {'parent_page_id': 3, 'child_page_id': 1}
# {'parent_page_id': 4, 'child_page_id': 10}
# {'parent_page_id': 4, 'child_page_id': 11}
# {'parent_page_id': 4, 'child_page_id': 12}
# {'parent_page_id': 4, 'child_page_id': 1}
# {'parent_page_id': 5, 'child_page_id': 1}
# {'parent_page_id': 5, 'child_page_id': 13}
# {'parent_page_id': 5, 'child_page_id': 14}
# {'parent_page_id': 5, 'child_page_id': 15}
# {'parent_page_id': 5, 'child_page_id': 16}
# {'parent_page_id': 5, 'child_page_id': 17}
# {'parent_page_id': 5, 'child_page_id': 18}
# {'parent_page_id': 5, 'child_page_id': 19}
# {'parent_page_id': 5, 'child_page_id': 20}
# {'parent_page_id': 5, 'child_page_id': 21}
# {'parent_page_id': 5, 'child_page_id': 22}
# {'parent_page_id': 5, 'child_page_id': 23}
# {'parent_page_id': 5, 'child_page_id': 24}
# {'parent_page_id': 5, 'child_page_id': 25}
# {'parent_page_id': 5, 'child_page_id': 26}
# {'parent_page_id': 5, 'child_page_id': 27}
# {'parent_page_id': 5, 'child_page_id': 28}
# {'parent_page_id': 5, 'child_page_id': 29}
# {'parent_page_id': 5, 'child_page_id': 30}
# {'parent_page_id': 5, 'child_page_id': 31}
# {'parent_page_id': 5, 'child_page_id': 32}
# {'parent_page_id': 5, 'child_page_id': 33}
# {'parent_page_id': 5, 'child_page_id': 34}
# {'parent_page_id': 5, 'child_page_id': 35}
# {'parent_page_id': 5, 'child_page_id': 36}
# {'parent_page_id': 5, 'child_page_id': 37}
# {'parent_page_id': 5, 'child_page_id': 38}
# {'parent_page_id': 5, 'child_page_id': 39}
# {'parent_page_id': 5, 'child_page_id': 40}
# {'parent_page_id': 5, 'child_page_id': 41}
# {'parent_page_id': 5, 'child_page_id': 42}
# {'parent_page_id': 5, 'child_page_id': 43}
# {'parent_page_id': 5, 'child_page_id': 44}
# {'parent_page_id': 5, 'child_page_id': 45}
# {'parent_page_id': 5, 'child_page_id': 46}
# {'parent_page_id': 5, 'child_page_id': 47}
# {'parent_page_id': 5, 'child_page_id': 48}
# {'parent_page_id': 5, 'child_page_id': 49}
# {'parent_page_id': 5, 'child_page_id': 50}
# {'parent_page_id': 5, 'child_page_id': 51}
# {'parent_page_id': 5, 'child_page_id': 52}
# {'parent_page_id': 5, 'child_page_id': 53}
# {'parent_page_id': 5, 'child_page_id': 54}
# {'parent_page_id': 5, 'child_page_id': 55}
# {'parent_page_id': 5, 'child_page_id': 56}
# {'parent_page_id': 5, 'child_page_id': 57}
# {'parent_page_id': 5, 'child_page_id': 58}
# {'parent_page_id': 5, 'child_page_id': 59}
# {'parent_page_id': 5, 'child_page_id': 60}
# {'parent_page_id': 5, 'child_page_id': 61}
# {'parent_page_id': 5, 'child_page_id': 62}
# {'parent_page_id': 5, 'child_page_id': 63}
# {'parent_page_id': 5, 'child_page_id': 64}
# {'parent_page_id': 5, 'child_page_id': 65}
# {'parent_page_id': 5, 'child_page_id': 66}
# {'parent_page_id': 5, 'child_page_id': 67}
# {'parent_page_id': 5, 'child_page_id': 68}
# {'parent_page_id': 5, 'child_page_id': 69}
# {'parent_page_id': 5, 'child_page_id': 70}
# {'parent_page_id': 5, 'child_page_id': 71}
# {'parent_page_id': 5, 'child_page_id': 72}
# {'parent_page_id': 5, 'child_page_id': 73}
# {'parent_page_id': 5, 'child_page_id': 74}
# {'parent_page_id': 5, 'child_page_id': 75}
# {'parent_page_id': 5, 'child_page_id': 76}
# {'parent_page_id': 5, 'child_page_id': 77}
# {'parent_page_id': 5, 'child_page_id': 78}
# {'parent_page_id': 5, 'child_page_id': 79}
# {'parent_page_id': 5, 'child_page_id': 80}
# {'parent_page_id': 5, 'child_page_id': 81}
# {'parent_page_id': 5, 'child_page_id': 82}
# {'parent_page_id': 5, 'child_page_id': 83}
# {'parent_page_id': 5, 'child_page_id': 84}
# {'parent_page_id': 5, 'child_page_id': 85}
# {'parent_page_id': 5, 'child_page_id': 86}
# {'parent_page_id': 5, 'child_page_id': 87}
# {'parent_page_id': 5, 'child_page_id': 88}
# {'parent_page_id': 5, 'child_page_id': 89}
# {'parent_page_id': 5, 'child_page_id': 90}
# {'parent_page_id': 5, 'child_page_id': 91}
# {'parent_page_id': 5, 'child_page_id': 92}
# {'parent_page_id': 5, 'child_page_id': 93}
# {'parent_page_id': 5, 'child_page_id': 94}
# {'parent_page_id': 5, 'child_page_id': 95}
# {'parent_page_id': 5, 'child_page_id': 96}
# {'parent_page_id': 5, 'child_page_id': 97}
# {'parent_page_id': 5, 'child_page_id': 98}
# {'parent_page_id': 5, 'child_page_id': 99}
# {'parent_page_id': 5, 'child_page_id': 100}
# {'parent_page_id': 5, 'child_page_id': 101}
# {'parent_page_id': 5, 'child_page_id': 102}
# {'parent_page_id': 5, 'child_page_id': 103}
# {'parent_page_id': 5, 'child_page_id': 104}
# {'parent_page_id': 5, 'child_page_id': 105}
# {'parent_page_id': 5, 'child_page_id': 106}
# {'parent_page_id': 5, 'child_page_id': 107}
# {'parent_page_id': 5, 'child_page_id': 108}
# {'parent_page_id': 5, 'child_page_id': 109}
# {'parent_page_id': 5, 'child_page_id': 110}
# {'parent_page_id': 5, 'child_page_id': 111}
# {'parent_page_id': 5, 'child_page_id': 112}
# {'parent_page_id': 5, 'child_page_id': 113}
# {'parent_page_id': 5, 'child_page_id': 114}
# {'parent_page_id': 5, 'child_page_id': 115}
# {'parent_page_id': 5, 'child_page_id': 116}
# {'parent_page_id': 5, 'child_page_id': 117}
# {'parent_page_id': 5, 'child_page_id': 118}
# {'parent_page_id': 5, 'child_page_id': 119}
# {'parent_page_id': 5, 'child_page_id': 120}
# {'parent_page_id': 5, 'child_page_id': 121}
# {'parent_page_id': 5, 'child_page_id': 122}
# {'parent_page_id': 5, 'child_page_id': 123}
# {'parent_page_id': 5, 'child_page_id': 124}
# {'parent_page_id': 5, 'child_page_id': 125}
# {'parent_page_id': 5, 'child_page_id': 126}
# {'parent_page_id': 5, 'child_page_id': 127}
# {'parent_page_id': 5, 'child_page_id': 128}
# {'parent_page_id': 5, 'child_page_id': 129}
# {'parent_page_id': 5, 'child_page_id': 130}
# {'parent_page_id': 5, 'child_page_id': 131}
# {'parent_page_id': 5, 'child_page_id': 132}
# {'parent_page_id': 5, 'child_page_id': 133}
# {'parent_page_id': 5, 'child_page_id': 134}
# {'parent_page_id': 5, 'child_page_id': 135}
# {'parent_page_id': 5, 'child_page_id': 136}
# {'parent_page_id': 5, 'child_page_id': 137}
# {'parent_page_id': 5, 'child_page_id': 138}
# {'parent_page_id': 5, 'child_page_id': 139}
# {'parent_page_id': 5, 'child_page_id': 140}
# {'parent_page_id': 5, 'child_page_id': 141}
# {'parent_page_id': 5, 'child_page_id': 142}
# {'parent_page_id': 5, 'child_page_id': 143}
# {'parent_page_id': 5, 'child_page_id': 144}
# {'parent_page_id': 5, 'child_page_id': 145}
# {'parent_page_id': 5, 'child_page_id': 146}
# {'parent_page_id': 5, 'child_page_id': 147}
# {'parent_page_id': 5, 'child_page_id': 148}
# {'parent_page_id': 5, 'child_page_id': 149}
# {'parent_page_id': 5, 'child_page_id': 150}
# {'parent_page_id': 5, 'child_page_id': 151}
# {'parent_page_id': 5, 'child_page_id': 152}
# {'parent_page_id': 5, 'child_page_id': 153}
# {'parent_page_id': 5, 'child_page_id': 154}
# {'parent_page_id': 5, 'child_page_id': 155}
# {'parent_page_id': 5, 'child_page_id': 156}
# {'parent_page_id': 5, 'child_page_id': 157}
# {'parent_page_id': 5, 'child_page_id': 158}
# {'parent_page_id': 5, 'child_page_id': 159}
# {'parent_page_id': 5, 'child_page_id': 160}
# {'parent_page_id': 5, 'child_page_id': 161}
# {'parent_page_id': 5, 'child_page_id': 162}
# {'parent_page_id': 5, 'child_page_id': 163}
# {'parent_page_id': 5, 'child_page_id': 164}
# {'parent_page_id': 5, 'child_page_id': 165}
# {'parent_page_id': 5, 'child_page_id': 166}
# {'parent_page_id': 5, 'child_page_id': 167}
# {'parent_page_id': 5, 'child_page_id': 168}
# {'parent_page_id': 5, 'child_page_id': 169}
# {'parent_page_id': 5, 'child_page_id': 170}
# {'parent_page_id': 5, 'child_page_id': 171}
# {'parent_page_id': 5, 'child_page_id': 172}
# {'parent_page_id': 5, 'child_page_id': 173}
# {'parent_page_id': 5, 'child_page_id': 174}
# {'parent_page_id': 5, 'child_page_id': 175}
# {'parent_page_id': 5, 'child_page_id': 176}
# {'parent_page_id': 5, 'child_page_id': 177}
# {'parent_page_id': 5, 'child_page_id': 178}
# {'parent_page_id': 5, 'child_page_id': 179}
# {'parent_page_id': 5, 'child_page_id': 180}
# {'parent_page_id': 5, 'child_page_id': 181}
# {'parent_page_id': 5, 'child_page_id': 182}
# {'parent_page_id': 5, 'child_page_id': 183}
# {'parent_page_id': 5, 'child_page_id': 184}
# {'parent_page_id': 5, 'child_page_id': 185}
# {'parent_page_id': 5, 'child_page_id': 186}
# {'parent_page_id': 5, 'child_page_id': 187}
# {'parent_page_id': 5, 'child_page_id': 188}
# {'parent_page_id': 5, 'child_page_id': 189}
# {'parent_page_id': 5, 'child_page_id': 190}
# {'parent_page_id': 5, 'child_page_id': 191}
# {'parent_page_id': 5, 'child_page_id': 192}
# {'parent_page_id': 5, 'child_page_id': 193}
# {'parent_page_id': 5, 'child_page_id': 194}
# {'parent_page_id': 5, 'child_page_id': 195}
# {'parent_page_id': 5, 'child_page_id': 196}
# {'parent_page_id': 5, 'child_page_id': 197}
# {'parent_page_id': 5, 'child_page_id': 198}
# {'parent_page_id': 5, 'child_page_id': 199}
# {'parent_page_id': 5, 'child_page_id': 200}
# {'parent_page_id': 5, 'child_page_id': 201}
# {'parent_page_id': 5, 'child_page_id': 202}
# {'parent_page_id': 5, 'child_page_id': 203}
# {'parent_page_id': 5, 'child_page_id': 204}
# {'parent_page_id': 5, 'child_page_id': 205}
# {'parent_page_id': 5, 'child_page_id': 206}
# {'parent_page_id': 5, 'child_page_id': 207}
# {'parent_page_id': 5, 'child_page_id': 208}
# {'parent_page_id': 5, 'child_page_id': 209}
# {'parent_page_id': 5, 'child_page_id': 210}
# {'parent_page_id': 5, 'child_page_id': 211}
# {'parent_page_id': 5, 'child_page_id': 212}
# {'parent_page_id': 5, 'child_page_id': 213}
# {'parent_page_id': 5, 'child_page_id': 214}
# {'parent_page_id': 5, 'child_page_id': 215}
# {'parent_page_id': 5, 'child_page_id': 216}
# {'parent_page_id': 5, 'child_page_id': 217}
# {'parent_page_id': 5, 'child_page_id': 218}
# {'parent_page_id': 5, 'child_page_id': 219}
# {'parent_page_id': 5, 'child_page_id': 220}
# {'parent_page_id': 5, 'child_page_id': 221}
# {'parent_page_id': 5, 'child_page_id': 222}
# {'parent_page_id': 5, 'child_page_id': 223}
# {'parent_page_id': 5, 'child_page_id': 224}
# {'parent_page_id': 5, 'child_page_id': 225}
# {'parent_page_id': 5, 'child_page_id': 226}
# {'parent_page_id': 5, 'child_page_id': 227}
# {'parent_page_id': 5, 'child_page_id': 228}
# {'parent_page_id': 5, 'child_page_id': 229}
# {'parent_page_id': 5, 'child_page_id': 230}
# {'parent_page_id': 5, 'child_page_id': 231}
# {'parent_page_id': 5, 'child_page_id': 232}
# {'parent_page_id': 5, 'child_page_id': 233}
# {'parent_page_id': 5, 'child_page_id': 234}
# {'parent_page_id': 5, 'child_page_id': 235}
# {'parent_page_id': 5, 'child_page_id': 236}
# {'parent_page_id': 5, 'child_page_id': 237}
# {'parent_page_id': 5, 'child_page_id': 238}
# {'parent_page_id': 5, 'child_page_id': 239}
# {'parent_page_id': 5, 'child_page_id': 240}
# {'parent_page_id': 5, 'child_page_id': 241}
# {'parent_page_id': 5, 'child_page_id': 242}
# {'parent_page_id': 5, 'child_page_id': 243}
# {'parent_page_id': 5, 'child_page_id': 244}
# {'parent_page_id': 5, 'child_page_id': 245}
# {'parent_page_id': 5, 'child_page_id': 246}
# {'parent_page_id': 5, 'child_page_id': 247}
# {'parent_page_id': 5, 'child_page_id': 248}
# {'parent_page_id': 5, 'child_page_id': 249}
# {'parent_page_id': 5, 'child_page_id': 250}
# {'parent_page_id': 5, 'child_page_id': 251}
# {'parent_page_id': 5, 'child_page_id': 252}
# {'parent_page_id': 5, 'child_page_id': 253}
# {'parent_page_id': 5, 'child_page_id': 254}
# {'parent_page_id': 5, 'child_page_id': 255}
# {'parent_page_id': 5, 'child_page_id': 256}
# {'parent_page_id': 5, 'child_page_id': 257}
# {'parent_page_id': 5, 'child_page_id': 258}
# {'parent_page_id': 5, 'child_page_id': 259}
# {'parent_page_id': 5, 'child_page_id': 260}
# {'parent_page_id': 5, 'child_page_id': 261}
# {'parent_page_id': 5, 'child_page_id': 262}
# {'parent_page_id': 5, 'child_page_id': 263}
# {'parent_page_id': 5, 'child_page_id': 264}
# {'parent_page_id': 5, 'child_page_id': 265}
# {'parent_page_id': 5, 'child_page_id': 266}
# {'parent_page_id': 5, 'child_page_id': 267}
# {'parent_page_id': 5, 'child_page_id': 268}
# {'parent_page_id': 5, 'child_page_id': 269}
# {'parent_page_id': 5, 'child_page_id': 270}
# {'parent_page_id': 5, 'child_page_id': 271}
# {'parent_page_id': 5, 'child_page_id': 272}
# {'parent_page_id': 5, 'child_page_id': 273}
# {'parent_page_id': 5, 'child_page_id': 274}
# {'parent_page_id': 5, 'child_page_id': 275}
# {'parent_page_id': 5, 'child_page_id': 276}
# {'parent_page_id': 5, 'child_page_id': 277}
# {'parent_page_id': 5, 'child_page_id': 278}
# {'parent_page_id': 5, 'child_page_id': 279}
# {'parent_page_id': 5, 'child_page_id': 280}
# {'parent_page_id': 5, 'child_page_id': 281}
# {'parent_page_id': 5, 'child_page_id': 282}
# {'parent_page_id': 5, 'child_page_id': 283}
# {'parent_page_id': 5, 'child_page_id': 284}
# {'parent_page_id': 5, 'child_page_id': 285}
# {'parent_page_id': 5, 'child_page_id': 286}
# {'parent_page_id': 5, 'child_page_id': 287}
# {'parent_page_id': 5, 'child_page_id': 288}
# {'parent_page_id': 5, 'child_page_id': 289}
# {'parent_page_id': 5, 'child_page_id': 290}
# {'parent_page_id': 5, 'child_page_id': 291}
# {'parent_page_id': 5, 'child_page_id': 292}
# {'parent_page_id': 5, 'child_page_id': 1}
# {'parent_page_id': 6, 'child_page_id': 2}
# {'parent_page_id': 7, 'child_page_id': 2}
# {'parent_page_id': 8, 'child_page_id': 293}
# {'parent_page_id': 8, 'child_page_id': 294}
# {'parent_page_id': 8, 'child_page_id': 295}
# {'parent_page_id': 8, 'child_page_id': 3}
# {'parent_page_id': 9, 'child_page_id': 296}
# {'parent_page_id': 9, 'child_page_id': 297}
# {'parent_page_id': 9, 'child_page_id': 3}
# {'parent_page_id': 10, 'child_page_id': 4}
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33228\96949196.py:168: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   result = self.es.search(index='web_page_structure', body=query)

# %%
spider.view_reverse_web_page_structure_data()
# Out:
# {'child_page_id': 2, 'parent_page_id': 1}
# {'child_page_id': 3, 'parent_page_id': 1}
# {'child_page_id': 4, 'parent_page_id': 1}
# {'child_page_id': 5, 'parent_page_id': 1}
# {'child_page_id': 6, 'parent_page_id': 2}
# {'child_page_id': 7, 'parent_page_id': 2}
# {'child_page_id': 1, 'parent_page_id': 2}
# {'child_page_id': 8, 'parent_page_id': 3}
# {'child_page_id': 9, 'parent_page_id': 3}
# {'child_page_id': 1, 'parent_page_id': 3}
# {'child_page_id': 10, 'parent_page_id': 4}
# {'child_page_id': 11, 'parent_page_id': 4}
# {'child_page_id': 12, 'parent_page_id': 4}
# {'child_page_id': 1, 'parent_page_id': 4}
# {'child_page_id': 1, 'parent_page_id': 5}
# {'child_page_id': 13, 'parent_page_id': 5}
# {'child_page_id': 14, 'parent_page_id': 5}
# {'child_page_id': 15, 'parent_page_id': 5}
# {'child_page_id': 16, 'parent_page_id': 5}
# {'child_page_id': 17, 'parent_page_id': 5}
# {'child_page_id': 18, 'parent_page_id': 5}
# {'child_page_id': 19, 'parent_page_id': 5}
# {'child_page_id': 20, 'parent_page_id': 5}
# {'child_page_id': 21, 'parent_page_id': 5}
# {'child_page_id': 22, 'parent_page_id': 5}
# {'child_page_id': 23, 'parent_page_id': 5}
# {'child_page_id': 24, 'parent_page_id': 5}
# {'child_page_id': 25, 'parent_page_id': 5}
# {'child_page_id': 26, 'parent_page_id': 5}
# {'child_page_id': 27, 'parent_page_id': 5}
# {'child_page_id': 28, 'parent_page_id': 5}
# {'child_page_id': 29, 'parent_page_id': 5}
# {'child_page_id': 30, 'parent_page_id': 5}
# {'child_page_id': 31, 'parent_page_id': 5}
# {'child_page_id': 32, 'parent_page_id': 5}
# {'child_page_id': 33, 'parent_page_id': 5}
# {'child_page_id': 34, 'parent_page_id': 5}
# {'child_page_id': 35, 'parent_page_id': 5}
# {'child_page_id': 36, 'parent_page_id': 5}
# {'child_page_id': 37, 'parent_page_id': 5}
# {'child_page_id': 38, 'parent_page_id': 5}
# {'child_page_id': 39, 'parent_page_id': 5}
# {'child_page_id': 40, 'parent_page_id': 5}
# {'child_page_id': 41, 'parent_page_id': 5}
# {'child_page_id': 42, 'parent_page_id': 5}
# {'child_page_id': 43, 'parent_page_id': 5}
# {'child_page_id': 44, 'parent_page_id': 5}
# {'child_page_id': 45, 'parent_page_id': 5}
# {'child_page_id': 46, 'parent_page_id': 5}
# {'child_page_id': 47, 'parent_page_id': 5}
# {'child_page_id': 48, 'parent_page_id': 5}
# {'child_page_id': 49, 'parent_page_id': 5}
# {'child_page_id': 50, 'parent_page_id': 5}
# {'child_page_id': 51, 'parent_page_id': 5}
# {'child_page_id': 52, 'parent_page_id': 5}
# {'child_page_id': 53, 'parent_page_id': 5}
# {'child_page_id': 54, 'parent_page_id': 5}
# {'child_page_id': 55, 'parent_page_id': 5}
# {'child_page_id': 56, 'parent_page_id': 5}
# {'child_page_id': 57, 'parent_page_id': 5}
# {'child_page_id': 58, 'parent_page_id': 5}
# {'child_page_id': 59, 'parent_page_id': 5}
# {'child_page_id': 60, 'parent_page_id': 5}
# {'child_page_id': 61, 'parent_page_id': 5}
# {'child_page_id': 62, 'parent_page_id': 5}
# {'child_page_id': 63, 'parent_page_id': 5}
# {'child_page_id': 64, 'parent_page_id': 5}
# {'child_page_id': 65, 'parent_page_id': 5}
# {'child_page_id': 66, 'parent_page_id': 5}
# {'child_page_id': 67, 'parent_page_id': 5}
# {'child_page_id': 68, 'parent_page_id': 5}
# {'child_page_id': 69, 'parent_page_id': 5}
# {'child_page_id': 70, 'parent_page_id': 5}
# {'child_page_id': 71, 'parent_page_id': 5}
# {'child_page_id': 72, 'parent_page_id': 5}
# {'child_page_id': 73, 'parent_page_id': 5}
# {'child_page_id': 74, 'parent_page_id': 5}
# {'child_page_id': 75, 'parent_page_id': 5}
# {'child_page_id': 76, 'parent_page_id': 5}
# {'child_page_id': 77, 'parent_page_id': 5}
# {'child_page_id': 78, 'parent_page_id': 5}
# {'child_page_id': 79, 'parent_page_id': 5}
# {'child_page_id': 80, 'parent_page_id': 5}
# {'child_page_id': 81, 'parent_page_id': 5}
# {'child_page_id': 82, 'parent_page_id': 5}
# {'child_page_id': 83, 'parent_page_id': 5}
# {'child_page_id': 84, 'parent_page_id': 5}
# {'child_page_id': 85, 'parent_page_id': 5}
# {'child_page_id': 86, 'parent_page_id': 5}
# {'child_page_id': 87, 'parent_page_id': 5}
# {'child_page_id': 88, 'parent_page_id': 5}
# {'child_page_id': 89, 'parent_page_id': 5}
# {'child_page_id': 90, 'parent_page_id': 5}
# {'child_page_id': 91, 'parent_page_id': 5}
# {'child_page_id': 92, 'parent_page_id': 5}
# {'child_page_id': 93, 'parent_page_id': 5}
# {'child_page_id': 94, 'parent_page_id': 5}
# {'child_page_id': 95, 'parent_page_id': 5}
# {'child_page_id': 96, 'parent_page_id': 5}
# {'child_page_id': 97, 'parent_page_id': 5}
# {'child_page_id': 98, 'parent_page_id': 5}
# {'child_page_id': 99, 'parent_page_id': 5}
# {'child_page_id': 100, 'parent_page_id': 5}
# {'child_page_id': 101, 'parent_page_id': 5}
# {'child_page_id': 102, 'parent_page_id': 5}
# {'child_page_id': 103, 'parent_page_id': 5}
# {'child_page_id': 104, 'parent_page_id': 5}
# {'child_page_id': 105, 'parent_page_id': 5}
# {'child_page_id': 106, 'parent_page_id': 5}
# {'child_page_id': 107, 'parent_page_id': 5}
# {'child_page_id': 108, 'parent_page_id': 5}
# {'child_page_id': 109, 'parent_page_id': 5}
# {'child_page_id': 110, 'parent_page_id': 5}
# {'child_page_id': 111, 'parent_page_id': 5}
# {'child_page_id': 112, 'parent_page_id': 5}
# {'child_page_id': 113, 'parent_page_id': 5}
# {'child_page_id': 114, 'parent_page_id': 5}
# {'child_page_id': 115, 'parent_page_id': 5}
# {'child_page_id': 116, 'parent_page_id': 5}
# {'child_page_id': 117, 'parent_page_id': 5}
# {'child_page_id': 118, 'parent_page_id': 5}
# {'child_page_id': 119, 'parent_page_id': 5}
# {'child_page_id': 120, 'parent_page_id': 5}
# {'child_page_id': 121, 'parent_page_id': 5}
# {'child_page_id': 122, 'parent_page_id': 5}
# {'child_page_id': 123, 'parent_page_id': 5}
# {'child_page_id': 124, 'parent_page_id': 5}
# {'child_page_id': 125, 'parent_page_id': 5}
# {'child_page_id': 126, 'parent_page_id': 5}
# {'child_page_id': 127, 'parent_page_id': 5}
# {'child_page_id': 128, 'parent_page_id': 5}
# {'child_page_id': 129, 'parent_page_id': 5}
# {'child_page_id': 130, 'parent_page_id': 5}
# {'child_page_id': 131, 'parent_page_id': 5}
# {'child_page_id': 132, 'parent_page_id': 5}
# {'child_page_id': 133, 'parent_page_id': 5}
# {'child_page_id': 134, 'parent_page_id': 5}
# {'child_page_id': 135, 'parent_page_id': 5}
# {'child_page_id': 136, 'parent_page_id': 5}
# {'child_page_id': 137, 'parent_page_id': 5}
# {'child_page_id': 138, 'parent_page_id': 5}
# {'child_page_id': 139, 'parent_page_id': 5}
# {'child_page_id': 140, 'parent_page_id': 5}
# {'child_page_id': 141, 'parent_page_id': 5}
# {'child_page_id': 142, 'parent_page_id': 5}
# {'child_page_id': 143, 'parent_page_id': 5}
# {'child_page_id': 144, 'parent_page_id': 5}
# {'child_page_id': 145, 'parent_page_id': 5}
# {'child_page_id': 146, 'parent_page_id': 5}
# {'child_page_id': 147, 'parent_page_id': 5}
# {'child_page_id': 148, 'parent_page_id': 5}
# {'child_page_id': 149, 'parent_page_id': 5}
# {'child_page_id': 150, 'parent_page_id': 5}
# {'child_page_id': 151, 'parent_page_id': 5}
# {'child_page_id': 152, 'parent_page_id': 5}
# {'child_page_id': 153, 'parent_page_id': 5}
# {'child_page_id': 154, 'parent_page_id': 5}
# {'child_page_id': 155, 'parent_page_id': 5}
# {'child_page_id': 156, 'parent_page_id': 5}
# {'child_page_id': 157, 'parent_page_id': 5}
# {'child_page_id': 158, 'parent_page_id': 5}
# {'child_page_id': 159, 'parent_page_id': 5}
# {'child_page_id': 160, 'parent_page_id': 5}
# {'child_page_id': 161, 'parent_page_id': 5}
# {'child_page_id': 162, 'parent_page_id': 5}
# {'child_page_id': 163, 'parent_page_id': 5}
# {'child_page_id': 164, 'parent_page_id': 5}
# {'child_page_id': 165, 'parent_page_id': 5}
# {'child_page_id': 166, 'parent_page_id': 5}
# {'child_page_id': 167, 'parent_page_id': 5}
# {'child_page_id': 168, 'parent_page_id': 5}
# {'child_page_id': 169, 'parent_page_id': 5}
# {'child_page_id': 170, 'parent_page_id': 5}
# {'child_page_id': 171, 'parent_page_id': 5}
# {'child_page_id': 172, 'parent_page_id': 5}
# {'child_page_id': 173, 'parent_page_id': 5}
# {'child_page_id': 174, 'parent_page_id': 5}
# {'child_page_id': 175, 'parent_page_id': 5}
# {'child_page_id': 176, 'parent_page_id': 5}
# {'child_page_id': 177, 'parent_page_id': 5}
# {'child_page_id': 178, 'parent_page_id': 5}
# {'child_page_id': 179, 'parent_page_id': 5}
# {'child_page_id': 180, 'parent_page_id': 5}
# {'child_page_id': 181, 'parent_page_id': 5}
# {'child_page_id': 182, 'parent_page_id': 5}
# {'child_page_id': 183, 'parent_page_id': 5}
# {'child_page_id': 184, 'parent_page_id': 5}
# {'child_page_id': 185, 'parent_page_id': 5}
# {'child_page_id': 186, 'parent_page_id': 5}
# {'child_page_id': 187, 'parent_page_id': 5}
# {'child_page_id': 188, 'parent_page_id': 5}
# {'child_page_id': 189, 'parent_page_id': 5}
# {'child_page_id': 190, 'parent_page_id': 5}
# {'child_page_id': 191, 'parent_page_id': 5}
# {'child_page_id': 192, 'parent_page_id': 5}
# {'child_page_id': 193, 'parent_page_id': 5}
# {'child_page_id': 194, 'parent_page_id': 5}
# {'child_page_id': 195, 'parent_page_id': 5}
# {'child_page_id': 196, 'parent_page_id': 5}
# {'child_page_id': 197, 'parent_page_id': 5}
# {'child_page_id': 198, 'parent_page_id': 5}
# {'child_page_id': 199, 'parent_page_id': 5}
# {'child_page_id': 200, 'parent_page_id': 5}
# {'child_page_id': 201, 'parent_page_id': 5}
# {'child_page_id': 202, 'parent_page_id': 5}
# {'child_page_id': 203, 'parent_page_id': 5}
# {'child_page_id': 204, 'parent_page_id': 5}
# {'child_page_id': 205, 'parent_page_id': 5}
# {'child_page_id': 206, 'parent_page_id': 5}
# {'child_page_id': 207, 'parent_page_id': 5}
# {'child_page_id': 208, 'parent_page_id': 5}
# {'child_page_id': 209, 'parent_page_id': 5}
# {'child_page_id': 210, 'parent_page_id': 5}
# {'child_page_id': 211, 'parent_page_id': 5}
# {'child_page_id': 212, 'parent_page_id': 5}
# {'child_page_id': 213, 'parent_page_id': 5}
# {'child_page_id': 214, 'parent_page_id': 5}
# {'child_page_id': 215, 'parent_page_id': 5}
# {'child_page_id': 216, 'parent_page_id': 5}
# {'child_page_id': 217, 'parent_page_id': 5}
# {'child_page_id': 218, 'parent_page_id': 5}
# {'child_page_id': 219, 'parent_page_id': 5}
# {'child_page_id': 220, 'parent_page_id': 5}
# {'child_page_id': 221, 'parent_page_id': 5}
# {'child_page_id': 222, 'parent_page_id': 5}
# {'child_page_id': 223, 'parent_page_id': 5}
# {'child_page_id': 224, 'parent_page_id': 5}
# {'child_page_id': 225, 'parent_page_id': 5}
# {'child_page_id': 226, 'parent_page_id': 5}
# {'child_page_id': 227, 'parent_page_id': 5}
# {'child_page_id': 228, 'parent_page_id': 5}
# {'child_page_id': 229, 'parent_page_id': 5}
# {'child_page_id': 230, 'parent_page_id': 5}
# {'child_page_id': 231, 'parent_page_id': 5}
# {'child_page_id': 232, 'parent_page_id': 5}
# {'child_page_id': 233, 'parent_page_id': 5}
# {'child_page_id': 234, 'parent_page_id': 5}
# {'child_page_id': 235, 'parent_page_id': 5}
# {'child_page_id': 236, 'parent_page_id': 5}
# {'child_page_id': 237, 'parent_page_id': 5}
# {'child_page_id': 238, 'parent_page_id': 5}
# {'child_page_id': 239, 'parent_page_id': 5}
# {'child_page_id': 240, 'parent_page_id': 5}
# {'child_page_id': 241, 'parent_page_id': 5}
# {'child_page_id': 242, 'parent_page_id': 5}
# {'child_page_id': 243, 'parent_page_id': 5}
# {'child_page_id': 244, 'parent_page_id': 5}
# {'child_page_id': 245, 'parent_page_id': 5}
# {'child_page_id': 246, 'parent_page_id': 5}
# {'child_page_id': 247, 'parent_page_id': 5}
# {'child_page_id': 248, 'parent_page_id': 5}
# {'child_page_id': 249, 'parent_page_id': 5}
# {'child_page_id': 250, 'parent_page_id': 5}
# {'child_page_id': 251, 'parent_page_id': 5}
# {'child_page_id': 252, 'parent_page_id': 5}
# {'child_page_id': 253, 'parent_page_id': 5}
# {'child_page_id': 254, 'parent_page_id': 5}
# {'child_page_id': 255, 'parent_page_id': 5}
# {'child_page_id': 256, 'parent_page_id': 5}
# {'child_page_id': 257, 'parent_page_id': 5}
# {'child_page_id': 258, 'parent_page_id': 5}
# {'child_page_id': 259, 'parent_page_id': 5}
# {'child_page_id': 260, 'parent_page_id': 5}
# {'child_page_id': 261, 'parent_page_id': 5}
# {'child_page_id': 262, 'parent_page_id': 5}
# {'child_page_id': 263, 'parent_page_id': 5}
# {'child_page_id': 264, 'parent_page_id': 5}
# {'child_page_id': 265, 'parent_page_id': 5}
# {'child_page_id': 266, 'parent_page_id': 5}
# {'child_page_id': 267, 'parent_page_id': 5}
# {'child_page_id': 268, 'parent_page_id': 5}
# {'child_page_id': 269, 'parent_page_id': 5}
# {'child_page_id': 270, 'parent_page_id': 5}
# {'child_page_id': 271, 'parent_page_id': 5}
# {'child_page_id': 272, 'parent_page_id': 5}
# {'child_page_id': 273, 'parent_page_id': 5}
# {'child_page_id': 274, 'parent_page_id': 5}
# {'child_page_id': 275, 'parent_page_id': 5}
# {'child_page_id': 276, 'parent_page_id': 5}
# {'child_page_id': 277, 'parent_page_id': 5}
# {'child_page_id': 278, 'parent_page_id': 5}
# {'child_page_id': 279, 'parent_page_id': 5}
# {'child_page_id': 280, 'parent_page_id': 5}
# {'child_page_id': 281, 'parent_page_id': 5}
# {'child_page_id': 282, 'parent_page_id': 5}
# {'child_page_id': 283, 'parent_page_id': 5}
# {'child_page_id': 284, 'parent_page_id': 5}
# {'child_page_id': 285, 'parent_page_id': 5}
# {'child_page_id': 286, 'parent_page_id': 5}
# {'child_page_id': 287, 'parent_page_id': 5}
# {'child_page_id': 288, 'parent_page_id': 5}
# {'child_page_id': 289, 'parent_page_id': 5}
# {'child_page_id': 290, 'parent_page_id': 5}
# {'child_page_id': 291, 'parent_page_id': 5}
# {'child_page_id': 292, 'parent_page_id': 5}
# {'child_page_id': 1, 'parent_page_id': 5}
# {'child_page_id': 2, 'parent_page_id': 6}
# {'child_page_id': 2, 'parent_page_id': 7}
# {'child_page_id': 293, 'parent_page_id': 8}
# {'child_page_id': 294, 'parent_page_id': 8}
# {'child_page_id': 295, 'parent_page_id': 8}
# {'child_page_id': 3, 'parent_page_id': 8}
# {'child_page_id': 296, 'parent_page_id': 9}
# {'child_page_id': 297, 'parent_page_id': 9}
# {'child_page_id': 3, 'parent_page_id': 9}
# {'child_page_id': 4, 'parent_page_id': 10}
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33228\96949196.py:180: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   result = self.es.search(index='reverse_web_page_structure', body=query)

# %% [markdown]
# #### env
# kibana 7.3.1 ;elasticsearch 7.3.1;python 3.9.1

# %%
# !pip list --format=freeze > requirements.txt

# %%
! pip list
# Out:
# Package            Version
# ------------------ -----------
# aiohappyeyeballs   2.4.4
# aiohttp            3.8.4
# aiosignal          1.3.1
# APScheduler        3.2.0
# asttokens          3.0.0
# async-timeout      4.0.2
# attrs              24.3.0
# backcall           0.2.0
# beautifulsoup4     4.12.2
# blinker            1.6.2
# Bottleneck         1.4.2
# Brotli             1.0.9
# bs4                0.0.1
# cchardet           2.1.7
# certifi            2023.5.7
# cffi               1.15.1
# chardet            3.0.4
# charset-normalizer 3.1.0
# click              8.0.1
# colorama           0.4.6
# comm               0.2.2
# cryptography       41.0.3
# cssselect          1.2.0
# debugpy            1.8.14
# decorator          5.2.1
# elastic-transport  7.16.0
# elasticsearch      7.17.9
# environs           9.5.0
# executing          2.1.0
# fake-headers       1.0.2
# Flask              2.3.2
# Flask-SQLAlchemy   3.0.5
# frozenlist         1.3.3
# gevent             21.12.0
# greenlet           1.1.3.post0
# gunicorn           19.9.0
# html5lib           1.1
# idna               2.7
# importlib-metadata 6.7.0
# ipykernel          6.29.5
# ipython            8.12.0
# itsdangerous       2.1.2
# jedi               0.19.2
# Jinja2             3.1.2
# jupyter_client     8.6.3
# jupyter_core       5.7.2
# loguru             0.7.0
# lxml               4.9.2
# MarkupSafe         2.0.1
# marshmallow        3.19.0
# matplotlib-inline  0.1.7
# maxminddb          2.3.0
# maxminddb-geolite2 2018.703
# mkl_fft            1.3.11
# mkl_random         1.2.8
# mkl-service        2.4.0
# multidict          6.0.4
# nest_asyncio       1.6.0
# numexpr            2.10.1
# numpy              1.26.4
# packaging          23.1
# pandas             2.2.3
# parso              0.8.4
# pickleshare        0.7.5
# pip                23.1.2
# platformdirs       4.3.7
# prompt_toolkit     3.0.51
# propcache          0.3.1
# psutil             7.0.0
# pure_eval          0.2.3
# pycparser          2.21
# Pygments           2.19.1
# pyOpenSSL          23.2.0
# pyquery            1.4.3
# PySocks            1.7.1
# python-dateutil    2.9.0.post0
# python-dotenv      1.0.0
# pytz               2023.3
# pywin32            307
# pyzmq              24.0.1
# redis              3.5.3
# requests           2.20.0
# retrying           1.3.4
# setuptools         67.8.0
# six                1.16.0
# soupsieve          2.4.1
# stack_data         0.6.3
# supervisor         4.2.5
# tornado            6.3.2
# traitlets          5.14.3
# typing_extensions  4.13.2
# tzdata             2023.3
# tzlocal            5.0.1
# urllib3            1.26.19
# wcwidth            0.2.13
# webencodings       0.5.1
# Werkzeug           2.3.6
# wheel              0.38.4
# win-inet-pton      1.1.0
# win32-setctime     1.1.0
# yarl               1.9.2
# zipp               3.15.0
# zope.event         5.0
# zope.interface     6.0
