# %% [markdown]
# #### crawler

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
from urllib.parse import urljoin
from elasticsearch import Elasticsearch
from datetime import datetime
import re
# real-----------------------------------------

class Spider:
    def __init__(self, start_url, max_pages):
        self.start_url = start_url
        self.max_pages = max_pages
        self.visited_urls = set()# 记录已访问的url
        self.url_map = {}  # 记录url和page_id的映射关系
        self.to_visit_urls = deque([start_url])
        self.page_count = 0
        self.page_id_counter = 1  # 用于分配唯一的 page_id
        # 初始化 Elasticsearch 客户端
        self.es = Elasticsearch("http://localhost:9200")
        # 创建网页信息索引
        
        # self.create_index('web_pages', {
        #     "mappings": {
        #         "properties": {
        #             "page_id": {"type": "integer"},
        #             "url": {"type": "keyword"},
        #             "title": {"type": "text"},
        #             "last_modify_time": {"type": "date"},
        #             "size": {"type": "integer"},
        #             "genre": {"type": "keyword"},  # 新增属性
        #             "plot_summary": {"type": "text"},  # 新增属性
        #             "plot_keywords": {"type": "keyword"},  # 新增属性
        #             "country": {"type": "keyword"},  # 新增属性
        #             "language": {"type": "keyword"},  # 新增属性
        #             "company": {"type": "keyword"} ,  # 新增属性
        #             "content": {"type": "text"}
        #         }
        #     }
        # })
        self.create_index('web_pages', {
            "mappings": {
                "properties": {
                    "page_id": {"type": "integer"},
                    "url": {"type": "keyword"},
                    "title": {"type": "text"},
                    "content": {"type": "text"},
                    "last_modify_time": {"type": "date"},
                    "size": {"type": "integer"}
                }
            }
        })
        self.create_index('web_extended_info', {
            "mappings": {
                "properties": {
                    "page_id": {"type": "integer"},
                    "genre": {"type": "keyword"},  # 新增属性
                    "plot_summary": {"type": "text"},  # 新增属性
                    "plot_keywords": {"type": "keyword"},  # 新增属性
                    "country": {"type": "keyword"},  # 新增属性
                    "language": {"type": "keyword"},  # 新增属性
                    "company": {"type": "keyword"} ,  # 新增属性
                }
            }
        })
        # 创建网页结构索引(parent, child)
        self.create_index('web_page_structure', {
            "mappings": {
                "properties": {
                    "parent_page_id": {"type": "integer"},
                    "child_page_id": {"type": "integer"}
                }
            }
        })
        # 创建反向网页结构索引（子 -> 父）
        self.create_index('reverse_web_page_structure', {
            "mappings": {
                "properties": {
                    "child_page_id": {"type": "integer"},
                    "parent_page_id": {"type": "integer"}
                }
            }
        })
        
        
        
        self.page_info_batch = []  # 暂存网页信息
        self.page_structure_batch = []  # 暂存网页结构信息
        self.reverse_page_structure_batch = []  # 暂存反向网页结构信息
        self.page_extended_info_batch = []  # 暂存网页扩展信息
        
        

    def create_index(self, index_name, mapping):
        # 检查索引是否存在
        if self.es.indices.exists(index=index_name):
            # 如果存在，则删除该索引
            self.es.indices.delete(index=index_name)
            print(f"索引 {index_name} 已删除")
        # 创建新的索引
        self.es.indices.create(index=index_name, body=mapping)
        print(f"索引 {index_name} 创建成功")

    def fetch_page_links(self, url):
        try:
            response = requests.get(url)
            if response.status_code == 200:
                # 检查 HTTP 头中的 Last-Modified 字段
                last_modified = response.headers.get('Last-Modified')
                if last_modified:
                    last_modify_time = datetime.strptime(last_modified, '%a, %d %b %Y %H:%M:%S %Z')
                else:
                    last_modify_time = datetime.now()
                # soup = BeautifulSoup(response.text, 'html.parser')
                # title = soup.title.string if soup.title else ''
                # content =soup.body.get_text(separator='\n')#.replace('\n', '').replace('\r', '')
                
                
                soup = BeautifulSoup(response.text, 'lxml')
                title = soup.title.string if soup.title else ''
                content = soup.get_text(separator='\n')  # 获取网页正文内容


                # genre_match = re.search(r'Genre:\s*(.*?)(?=[^ \n].*?:)',content)
                genre_match = re.search(  r'Genre:\s*(.*?)(?=\n(?!\n)(?=[A-Z])|more)', content, re.DOTALL)
                if genre_match:
                    genre = genre_match.group(1).strip().split('/')
                    genre = [g.strip() for g in genre if g.strip()]  # 去除空格和空字符串
                
                plot_summary_match = re.search(r'Plot Summary:\s*(.*?)(?=\n(?!\n)(?=[A-Z])|more)', content, re.DOTALL)
                if plot_summary_match:
                    plot_summary = plot_summary_match.group(1).strip()
                
                plot_keywords_match = re.search( r'Plot Keywords:\s*([\s\S]*?)(?=\n[^\n:]*:|more|\Z)', content, re.DOTALL)
                if plot_keywords_match:
                    plot_keywords = plot_keywords_match.group(1).strip().split('/')
                    plot_keywords = [pk.replace('\xa0',' ').strip() for pk in plot_keywords if pk.strip()]   
                
                country_match = re.search(r'Country:\s*(.*?)(?=\n\w+:|\Z)', content, re.DOTALL)
                if country_match:
                    country = country_match.group(1).strip().split('/')
                    country = [c.strip() for c in country if c.strip()]   
                
                language_match = re.search(r'Language:\s*(.*?)(?=\n\w+:|\Z)', content, re.DOTALL)
                if language_match:
                    language = language_match.group(1).strip().split('/')
                    language = [l.strip() for l in language if l.strip()]   
                
                company_match = re.search(r'Company:\s*(.*?)(?=\n(?!\n)(?=[A-Z])|more)', content, re.DOTALL)
                if company_match:
                    company = company_match.group(1).strip().split('/')
                    company = [c.strip() for c in company if c.strip()]  
                            
                size=response.raw._fp_bytes_read if response.raw._fp_bytes_read else 0

                # 没访问过且没分配过id
                if url not in self.url_map:
                    page_id = self.page_id_counter
                    self.page_id_counter += 1
                    self.url_map[url] = page_id
                # 没访问过但分配过id
                else:
                    page_id = self.url_map[url]
                # 存储网页信息到 Elasticsearch
                
                self.page_info_batch.append({
                    "page_id": page_id,
                    "url": url,
                    "title": title,
                    "content": content.replace('\n', '').replace('\r', ''),
                    "last_modify_time": last_modify_time,
                    "size": size,
                })
                self.page_extended_info_batch.append({
                    "page_id": page_id,
                    "genre": genre if 'genre' in locals() else [],
                    "plot_summary": plot_summary if 'plot_summary' in locals() else '',
                    "plot_keywords": plot_keywords if 'plot_keywords' in locals() else [],
                    "country": country if 'country' in locals() else [],
                    "language": language if 'language' in locals() else [],
                    "company": company if 'company' in locals() else []
                })
                # self.store_page_info(page_id, url, title, content, last_modify_time,size)

                links = [link.get('href') for link in soup.find_all('a', href=True)]
                return page_id, links
            return None, []
        except requests.RequestException as e:
            print(f"Failed to fetch {url}: {e}")
            return None, []

    def store_page_info(self):
        for doc in self.page_info_batch:
            # 批量存储网页信息到 Elasticsearch
            self.es.index(index='web_pages', id=doc['page_id'], body=doc)
        self.page_info_batch=[]  # 清空批量存储列表
        for doc in self.page_extended_info_batch:
            # 批量存储网页扩展信息到 Elasticsearch
            self.es.index(index='web_extended_info', id=doc['page_id'], body=doc)
        self.page_extended_info_batch=[]  # 清空批量存储列表
        # self.es.index(index='web_pages', id=page_id, body=doc)

    def store_page_structure(self):
        for doc in self.page_structure_batch:
            self.es.index(index='web_page_structure', body=doc)
        self.page_structure_batch = []
        for doc in self.reverse_page_structure_batch:
            self.es.index(index='reverse_web_page_structure', body=doc)
        self.reverse_page_structure_batch = []

    def crawl(self,batch_size=20):
        while self.to_visit_urls and self.page_count < self.max_pages:
            url = self.to_visit_urls.popleft()
            if url in self.visited_urls:
                continue
            print(f"Crawling: {url}")
            self.visited_urls.add(url)
            self.page_count += 1
            parent_page_id, links = self.fetch_page_links(url)#肯定没访问过
            if parent_page_id:
                for link in links:
                    new_full_url = urljoin(url, link)
                    
                    # 没分配过id(没访问过   )
                    if new_full_url not in self.url_map:
                        child_page_id = self.page_id_counter
                        self.page_id_counter += 1
                        self.url_map[new_full_url] = child_page_id
                        self.to_visit_urls.append(new_full_url)
                    # 已分配过id(没访问过)
                    elif new_full_url in self.url_map and new_full_url not in self.visited_urls:
                        child_page_id = self.url_map[new_full_url]
                        self.to_visit_urls.append(new_full_url)
                    # 已访问过(已分配过id)
                    elif new_full_url in self.visited_urls:
                        child_page_id = self.url_map[new_full_url]
                    
                    # self.store_page_structure(parent_page_id, child_page_id)
                    self.page_structure_batch.append({
                        "parent_page_id": parent_page_id,
                        "child_page_id": child_page_id
                    })
                    self.reverse_page_structure_batch.append({
                        "child_page_id": child_page_id,
                        "parent_page_id": parent_page_id
                    })
                
                if len(self.page_structure_batch) >= batch_size:
                    self.store_page_info()
                if len(self.reverse_page_structure_batch) >= batch_size:
                    self.store_page_structure()
        # 爬取结束后，将剩余暂存的数据写入数据库
        if self.page_info_batch:
            self.store_page_info()
        if self.page_structure_batch or self.reverse_page_structure_batch:
            self.store_page_structure()
    
    def view_web_pages_data(self):
        """查看 web_pages 索引中的数据"""
        query = {
            "query": {
                "match_all": {}
            },
            "size": 1000
        }
        result = self.es.search(index='web_pages', body=query)
        for hit in result['hits']['hits']:
            print(hit['_source'])

    def view_web_page_structure_data(self):
        """查看 web_page_structure 索引中的数据"""
        query = {
            "query": {
                "match_all": {}
            },
            "size": 1000
        }
        result = self.es.search(index='web_page_structure', body=query)
        for hit in result['hits']['hits']:
            print(hit['_source'])
            
    def view_reverse_web_page_structure_data(self):
        """查看 reverse_web_page_structure 索引中的数据"""
        query = {
            "query": {
                "match_all": {}
            },
            "size": 1000
        }
        result = self.es.search(index='reverse_web_page_structure', body=query)
        for hit in result['hits']['hits']:
            print(hit['_source'])


if __name__ == "__main__":
    start_url = 'https://www.cse.ust.hk/~kwtleung/COMP4321/testpage.htm'
    max_pages = 300
    spider = Spider(start_url, max_pages)
    spider.crawl()

# %% [markdown]
# #### 新表示例

# %%
query = {
    "query": {
        "bool": {
            "must": [
                {
                    "exists": {
                        "field": "genre"
                    }
                }
            ]
        }
    },
    "size": 1000
        }
es=Elasticsearch("http://localhost:9200")
result = es.search(index='web_extended_info', body=query)
for hit in result['hits']['hits']:
    print(hit['_source'])
# Out:
# {'page_id': 21, 'genre': ['Sci-Fi', 'Comedy'], 'plot_summary': "The class of nuke 'em high is back, and this time they're in college! Tromaville's nuclear factory has...", 'plot_keywords': ['Sequel', 'Psychotronic', 'Troma Film', 'Cult Favorite', 'Troma'], 'country': ['USA'], 'language': ['English'], 'company': ['Troma Entertainment']}
# {'page_id': 24, 'genre': ['Comedy', 'Romance', 'Mystery'], 'plot_summary': "Baby photographer Ronnie Jackson, on death row in San Quentin, tells reporters how he got there: taking care of his private-eye neighbor's office...", 'plot_keywords': ['Brunette', 'Chase', 'Death Row', 'Detective', 'Frame Up'], 'country': ['USA'], 'language': ['English'], 'company': ['Hope Enterprises']}
# {'page_id': 27, 'genre': ['Documentary', 'Music'], 'plot_summary': '', 'plot_keywords': ['Concert Film', 'Country', 'Independent Film'], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 30, 'genre': ['Biography', 'Drama', 'Music', 'Romance'], 'plot_summary': 'As the tagline reveals, this movie deals with life and death of the legendary Ludwig van Beethoven. Beside all the work he is known for...', 'plot_keywords': ['Classical Music', 'Beethoven', 'Composer', 'Historical', 'Deafness'], 'country': ['UK', 'USA'], 'language': ['English'], 'company': ['Icon Entertainment International']}
# {'page_id': 32, 'genre': ['Adventure', 'Comedy', 'Romance', 'Drama', 'Family', 'Musical'], 'plot_summary': 'Seeta (Hema Malini) lives with her grandma (Pratima Devi) and her cruel aunt Kaushalya (Manorama), uncle Badrinath (Satyen Kappu)...', 'plot_keywords': ['Dual Role', 'Revenge', 'Circus', 'Gypsy', 'Twins'], 'country': ['India'], 'language': ['Hindi'], 'company': ['Sippy Films Pvt. Ltd.']}
# {'page_id': 33, 'genre': ['Drama', 'Comedy'], 'plot_summary': 'Jerry is a successful New York psychiatrist who is diagnosed with leukemia. When he tells his mother...', 'plot_keywords': [], 'country': ['UK', 'USA'], 'language': ['English'], 'company': ['Granada Television']}
# {'page_id': 34, 'genre': ['Comedy', 'Romance'], 'plot_summary': '', 'plot_keywords': ['Nonlinear Timeline', 'Comedy Of Errors', 'Satire', 'Acting Class', 'Filmmaking'], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 36, 'genre': ['Drama', 'Horror', 'Thriller'], 'plot_summary': "There's a big valentine-party planned in the little miningtown Valentine's Bluff. It is the first valentine party in 20 years...", 'plot_keywords': ['Axe', 'Serial Killer', 'Violence', 'Double Impalement', 'Gore'], 'country': ['Canada'], 'language': ['English'], 'company': ['Canadian Film Development Corporation (CFDC)']}
# {'page_id': 38, 'genre': ['Action', 'Crime', 'Drama', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Kingpin', 'Interracial Relationship', 'Bloodshed', 'Cocaine', 'Gunfight'], 'country': ['USA'], 'language': ['English'], 'company': ['Bloodline Films']}
# {'page_id': 42, 'genre': ['Comedy', 'Romance', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Golden Age', 'Lawyer', 'Hospital Gown', 'May December Romance', 'Aging'], 'country': ['USA'], 'language': ['English', 'French'], 'company': ['Columbia Pictures Corporation']}
# {'page_id': 43, 'genre': ['Documentary', 'Music'], 'plot_summary': '', 'plot_keywords': ['Obese', 'Rock Music', 'Independent Film', 'Character Name In Title'], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 47, 'genre': ['Animation', 'Family'], 'plot_summary': '', 'plot_keywords': ['Sequel', 'Kids And Family'], 'country': ['USA'], 'language': [], 'company': []}
# {'page_id': 49, 'genre': ['Action', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Martial Arts', 'Character Name In Title'], 'country': ['Japan'], 'language': ['Japanese'], 'company': ['Katsu Production Co. Ltd.']}
# {'page_id': 51, 'genre': ['Drama', 'Comedy'], 'plot_summary': '', 'plot_keywords': ['Homosexual', 'Gay Interest', 'AIDS', 'Campaign', 'Omnibus'], 'country': ['France'], 'language': ['French'], 'company': ['Canal+']}
# {'page_id': 52, 'genre': ['Action', 'Drama', 'Family'], 'plot_summary': '', 'plot_keywords': ['Americana', 'Baseball', 'Destiny', 'Fate', 'Love'], 'country': ['USA'], 'language': ['English'], 'company': ['Affinity Films Inc.']}
# {'page_id': 54, 'genre': ['Drama'], 'plot_summary': '', 'plot_keywords': ['Independent Film'], 'country': ['USA'], 'language': ['English'], 'company': ['Centre Street Productions']}
# {'page_id': 56, 'genre': ['Drama'], 'plot_summary': 'Percy, upon being released from prison, goes to the small town of Gillead, to find a place where she can start over again...', 'plot_keywords': ['Forgiveness', 'Maine', 'Ex Convict', 'Hermit', 'Restaurant'], 'country': ['USA'], 'language': ['English'], 'company': ['Castle Rock Entertainment']}
# {'page_id': 62, 'genre': ['Romance', 'War'], 'plot_summary': "Tyrone Power is a pilots' pilot, but he doesn't believe in anything beyond his own abilities. He gets...", 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['Twentieth Century-Fox Film Corporation']}
# {'page_id': 64, 'genre': ['Documentary'], 'plot_summary': '', 'plot_keywords': ['Federal Bureau Of Investigation', '1960s', 'Radicalism', 'Radical', 'Terrorism'], 'country': ['USA'], 'language': ['English'], 'company': ['The Free History Project']}
# {'page_id': 66, 'genre': ['Comedy', 'Romance'], 'plot_summary': '', 'plot_keywords': ['Marriage', 'Husband Wife Relationship', 'Wedding'], 'country': ['USA'], 'language': ['English'], 'company': ['Twentieth Century-Fox Film Corporation']}
# {'page_id': 67, 'genre': ['Action', 'Crime', 'Thriller', 'Drama'], 'plot_summary': 'Someone does a nasty hatchet job on a San Fransisco big noise and the Assistant D.A. takes charge of the investigation...', 'plot_keywords': ['Parade', 'Car Chase', 'Brake Failure', 'Cocaine', 'Chase'], 'country': ['USA'], 'language': ['English'], 'company': ['Paramount Pictures']}
# {'page_id': 69, 'genre': ['Drama', 'War'], 'plot_summary': '', 'plot_keywords': ['Psychopath', 'Shot In The Head', '1930s', 'Breaking The Fourth Wall', 'Cripple'], 'country': ['UK', 'USA'], 'language': ['English'], 'company': ['Bayly', 'Paré Productions']}
# {'page_id': 70, 'genre': ['Action', 'Fantasy', 'Adventure'], 'plot_summary': '', 'plot_keywords': ['Queen', 'Cynic', 'Loss Of Father', 'Tyrant', 'Good Versus Evil'], 'country': ['USA'], 'language': ['English'], 'company': ['Universal Pictures']}
# {'page_id': 71, 'genre': ['Comedy', 'Romance'], 'plot_summary': '', 'plot_keywords': [], 'country': ['Hong Kong'], 'language': ['Cantonese'], 'company': []}
# {'page_id': 73, 'genre': ['Documentary', 'Music'], 'plot_summary': '', 'plot_keywords': ['Latin', 'Live', 'Pop Music', 'Song', 'Concert Film'], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 75, 'genre': ['Drama', 'Romance', 'War'], 'plot_summary': '', 'plot_keywords': ['U Boat', 'Love Triangle', 'Submarine', 'US Navy', 'WWII'], 'country': ['USA'], 'language': ['English', 'German'], 'company': ['Twentieth Century-Fox Film Corporation']}
# {'page_id': 77, 'genre': ['Comedy', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Drag Queen', 'Drug Abuse', 'Gay Interest', 'Heroin Addict', 'Hustler'], 'country': ['USA'], 'language': ['English'], 'company': ['Pershing Point Productions']}
# {'page_id': 79, 'genre': ['Horror'], 'plot_summary': '', 'plot_keywords': ['Bitten In The Throat', 'Sword', 'Vampire', 'Casino', 'Cemetery'], 'country': ['Romania', 'USA'], 'language': ['English'], 'company': ['Castel Film Romania']}
# {'page_id': 80, 'genre': ['Family', 'Animation', 'Comedy', 'Sci-Fi'], 'plot_summary': '', 'plot_keywords': ['Alien Invasion', 'Surreal', 'Alien Contact', 'Antenna', 'Anti Conformity'], 'country': ['USA', 'Philippines'], 'language': ['English'], 'company': ['Nicktoons Productions']}
# {'page_id': 83, 'genre': ['Documentary', 'Biography'], 'plot_summary': '', 'plot_keywords': ['Artist', 'Art', 'Monument', 'War Memorial', '1970s'], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 86, 'genre': ['Thriller', 'Action', 'Comedy'], 'plot_summary': 'A woman, fired from a financial coorporation during the Asia crisis, returns home with no money. However...', 'plot_keywords': ['Violence', 'Unemployed', 'Thailand', 'Corpse', 'Stabbing'], 'country': ['Thailand'], 'language': ['Thai'], 'company': ['Five Stars Production Company']}
# {'page_id': 87, 'genre': ['Drama'], 'plot_summary': '', 'plot_keywords': ['Adultery', 'Brother', 'Automobile', 'Drag Racing', 'Factory'], 'country': ['USA'], 'language': ['English'], 'company': ['Kodiak Productions LLC']}
# {'page_id': 89, 'genre': ['Action', 'Adventure', 'Mystery', 'Sci-Fi'], 'plot_summary': 'Greed is bad, this simple morality tale cautions. A megalomaniacal C.E.O. sends his son into the dangerous...', 'plot_keywords': ['Animal', 'Legend', 'Skydiving', 'White Water Rafting', 'Africa'], 'country': ['USA'], 'language': ['English'], 'company': ['Paramount Pictures']}
# {'page_id': 90, 'genre': ['Action', 'Family', 'Adventure', 'Comedy'], 'plot_summary': '', 'plot_keywords': ['Surprise After End Credits', 'Mall', 'Postman', 'Search', 'Superhero'], 'country': ['USA'], 'language': ['English'], 'company': ['1492 Pictures']}
# {'page_id': 92, 'genre': ['Drama', 'Thriller'], 'plot_summary': '19 years after President Timothy Keegan was assassinated, his brother Nick discovers a dying man claiming to have been the gunman...', 'plot_keywords': ['Satire', 'Assassination Of President', 'Assassination', 'Political', 'U.S. President'], 'country': ['USA'], 'language': ['English'], 'company': ['Winter Gold Productions']}
# {'page_id': 94, 'genre': ['Adventure', 'War', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Frogman', 'Military', 'Scuba Diving'], 'country': ['USA'], 'language': ['English'], 'company': ['Twentieth Century-Fox Film Corporation']}
# {'page_id': 95, 'genre': ['Biography', 'Drama', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Amazing Grace Hymn', 'Politics', 'Radiation', 'Nuclear Reactor', 'Historical'], 'country': ['USA'], 'language': ['English'], 'company': ['20th Century Fox']}
# {'page_id': 96, 'genre': ['Animation', 'Action', 'Comedy', 'Family', 'Fantasy', 'Adventure'], 'plot_summary': '', 'plot_keywords': ['Based On TV Series', 'Crime Fighter', 'Experiment', 'Superheroine', 'Kindergarten'], 'country': ['USA'], 'language': ['English'], 'company': ['Cartoon Network']}
# {'page_id': 99, 'genre': ['Comedy', 'Drama', 'Romance'], 'plot_summary': 'Marcin and Kaska are young lovers in a lousy little town in Poland. Marcin has just lost his father...', 'plot_keywords': ['Black Comedy', 'Romantic Comedy', 'Emigration', 'Funeral', 'Provincial Life'], 'country': ['Poland'], 'language': ['Polish'], 'company': ['Agencja Produkcji Filmowej']}
# {'page_id': 100, 'genre': ['Adventure', 'Animation', 'Fantasy'], 'plot_summary': '', 'plot_keywords': ['Anime', 'Sword And Sorcery', 'Remake', 'Based On Novel'], 'country': ['Japan'], 'language': ['English', 'Japanese'], 'company': []}
# {'page_id': 101, 'genre': ['Action', 'Adventure', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Voice Over', 'Airforce One', 'Exploding Truck', 'Exploding Ship', 'Blackmail'], 'country': ['France', 'USA'], 'language': ['English'], 'company': ['Chain of Command Inc.']}
# {'page_id': 106, 'genre': ['Documentary', 'Music'], 'plot_summary': '', 'plot_keywords': ['Concert Film', 'Rock Music'], 'country': ['USA'], 'language': ['English'], 'company': ['JBTV Chicago']}
# {'page_id': 107, 'genre': ['Comedy', 'Drama', 'Romance'], 'plot_summary': 'Rodolfo (Trevino) is a young bachelor doctor who has a love affair with a younger music student, Ramon (Meza)...', 'plot_keywords': ['Male Full Frontal Nudity', 'Homosexual', 'Mother', 'Gay Interest', 'Bisexual'], 'country': ['Mexico'], 'language': ['Spanish'], 'company': ['Clasa Films Mundiales']}
# {'page_id': 108, 'genre': ['Documentary'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['Discovery Channel']}
# {'page_id': 114, 'genre': ['Drama'], 'plot_summary': '', 'plot_keywords': ['Hell', 'Purgatory', 'Sarajevo', 'Music'], 'country': ['France', 'Switzerland'], 'language': ['French', 'Arabic', 'English', 'Hebrew', 'Serbo-Croatian', 'Spanish'], 'company': ['Avventura Films']}
# {'page_id': 118, 'genre': ['Documentary', 'Music'], 'plot_summary': '', 'plot_keywords': ['Concert'], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 120, 'genre': ['Crime', 'Drama', 'Mystery', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Gay Slur', 'Political Thriller', 'Politics', 'Abduction', 'Beach'], 'country': ['USA', 'Germany'], 'language': ['English', 'Russian', 'Swedish'], 'company': ['ApolloMedia']}
# {'page_id': 122, 'genre': ['Drama', 'History'], 'plot_summary': 'An English bon-vivant osteopath is enchanted with a young exotic dancer and invites her to live with him...', 'plot_keywords': ['Masochist', 'Orgy', 'Historical', 'Independent Film'], 'country': ['UK'], 'language': ['English'], 'company': ['British Screen Productions']}
# {'page_id': 124, 'genre': ['Documentary'], 'plot_summary': 'This movie is only made of archive pictures: the official newsreels that were broadcasted on French...', 'plot_keywords': ['WWII', 'Toulon', 'Air Raid', 'Agriculture', 'Unemployment'], 'country': ['France'], 'language': ['French'], 'company': ['Canal+']}
# {'page_id': 125, 'genre': ['Documentary'], 'plot_summary': 'Legendary martial artist Bruce Lee is the subject of this thoughtful documentary by Lee aficionado John Little...', 'plot_keywords': ['Martial Arts', 'Jeet Kune Do', 'Bruce Lee', 'Character Name In Title'], 'country': ['USA', 'UK', 'Hong Kong'], 'language': ['English', 'Cantonese'], 'company': []}
# {'page_id': 127, 'genre': ['Mystery'], 'plot_summary': "When one of the copy writers of Pym's Advertising Agency meets his death by falling down a spiral staircase...", 'plot_keywords': ['Advertising', 'Based On Novel'], 'country': ['UK'], 'language': ['English'], 'company': ['British Broadcasting Corporation (BBC)']}
# {'page_id': 129, 'genre': ['Comedy', 'Musical', 'Romance'], 'plot_summary': 'A musical remake of Ninotchka: After three bumbling Soviet agents fail in their mission to retrieve a straying Soviet composer from Paris...', 'plot_keywords': ['Cinemascope', 'Musical', 'Dancer', 'Song And Dance', 'Dance'], 'country': ['USA'], 'language': ['English'], 'company': ['Metro-Goldwyn-Mayer (MGM)']}
# {'page_id': 130, 'genre': ['Action'], 'plot_summary': 'John Rambo is removed from prison by his former superior, Colonel Samuel Troutman, for a top-secret...', 'plot_keywords': ['Gatling Gun', 'Python', 'Compound Bow', 'Helicopter', 'Chosen One'], 'country': ['USA'], 'language': ['English'], 'company': ['Anabasis N.V.']}
# {'page_id': 131, 'genre': ['Documentary\n(Credited cast)Chris Cound ... Host'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['EFP']}
# {'page_id': 132, 'genre': ['Drama', 'Romance'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['Down Home Entertainment']}
# {'page_id': 133, 'genre': ['Music\n(Credited cast)Carmit Bachar ... DancerBeyoncé Knowles ... Herself'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['Sanctuary Group Ltd.']}
# {'page_id': 134, 'genre': ['Horror', 'Sci-Fi', 'Thriller'], 'plot_summary': 'Eight strangers find themselves waking up in a strange cube-shaped room with no recollection of how they came to be there...', 'plot_keywords': ['Blind Girl', 'Death', 'Hypercube', 'Sequel', 'Blind'], 'country': ['Canada'], 'language': ['English'], 'company': ['Ghost Logic']}
# {'page_id': 135, 'genre': ['Comedy', 'Crime'], 'plot_summary': '', 'plot_keywords': ['Baby Sitting', 'Barbershop', 'Coin', 'Dog Bite', 'Dog'], 'country': ['USA'], 'language': ['English'], 'company': ['Bel Air Entertainment']}
# {'page_id': 137, 'genre': ['Action', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Anti Terrorism', 'Police', 'El Train', 'Bus', 'Cable Car'], 'country': ['USA'], 'language': ['French', 'German', 'English'], 'company': ['Martin Poll Productions']}
# {'page_id': 139, 'genre': ['Action', 'Comedy', 'Crime', 'Drama'], 'plot_summary': 'Rita Rizzoli is a narcotics cop with a plethora of disguises. When a drug shipment is hijacked, the...', 'plot_keywords': ['Ford Mustang', 'Racial Slur', 'Drugs', 'Undercover', 'Police'], 'country': ['USA', 'Japan'], 'language': ['English'], 'company': ['CST Telecommunications']}
# {'page_id': 143, 'genre': ['Horror', 'Sci-Fi'], 'plot_summary': 'A man is taken to a small clinic in Guam with mysterious bites on him. This sparks a search for what could have caused such wounds...', 'plot_keywords': ['Native Tribe', 'B Horror', 'Giant Spider', 'Island', 'Spider'], 'country': ['Spain'], 'language': ['Spanish', 'English'], 'company': ['Castelao Producciones S.A.']}
# {'page_id': 145, 'genre': ['Comedy', 'Reality-TV'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['18 Husky']}
# {'page_id': 146, 'genre': ['Drama'], 'plot_summary': 'After John, a painter, and his wife move into an old house on an island, a seductive widow ghost shows up in mirrors...', 'plot_keywords': ['Ghost', 'Independent Film', 'Based On Book'], 'country': ['USA'], 'language': ['English'], 'company': ['The Black Entertainment Network']}
# {'page_id': 149, 'genre': ['Action', 'Crime', 'Drama', 'Thriller'], 'plot_summary': 'FBI agent Cara Landry is sent on an undercover assignment to gather evidence on Damian Medina, a Mexican...', 'plot_keywords': ['Betrayal', 'Suspense', 'Suspicion', 'Independent Film'], 'country': ['USA', 'Mexico'], 'language': ['English'], 'company': ['Hemisferio Films']}
# {'page_id': 154, 'genre': ['Comedy'], 'plot_summary': 'Major swindler Ferrari specializes in swindling the rich. Serious Crime Unit inspector Chan Foon is...', 'plot_keywords': [], 'country': ['Hong Kong'], 'language': ['Cantonese'], 'company': ['B.O.B. and Partners Ltd. Co.']}
# {'page_id': 157, 'genre': ['Comedy', 'Drama', 'Romance'], 'plot_summary': "Solange is depressed: she's stopped smiling, she eats little, she says less. She has fainting fits....", 'plot_keywords': ['Domestic Triangle', 'Human Relationship', 'Mozart', 'Teenage Boy', 'Breasts'], 'country': ['Belgium', 'France'], 'language': ['French'], 'company': ['Belga Films']}
# {'page_id': 158, 'genre': ['Action', 'Comedy'], 'plot_summary': 'The government hires a feminist at the local university to track down the Piranha Women living in the...', 'plot_keywords': ['Expedition', 'Gender Clash', 'Satire', 'Beer', 'Camping In Wilderness'], 'country': ['USA'], 'language': ['English'], 'company': ['Beyond Infinity']}
# {'page_id': 159, 'genre': ['Crime', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Psychological Drama', 'Independent Film'], 'country': ['USA'], 'language': ['English\nSound Mix:\nUltra Stereo'], 'company': []}
# {'page_id': 160, 'genre': ['Comedy', 'Drama', 'Romance'], 'plot_summary': 'Nelson (Keanu Reeves) is a man devoted to his advertising career in San Francisco. One day, while taking a driving test at the DMV...', 'plot_keywords': ['12 available'], 'country': ['USA'], 'language': ['English'], 'company': ['3 Art Entertainment']}
# {'page_id': 163, 'genre': ['Horror'], 'plot_summary': "A couple of friends party wildly at a vacation house. While they're drinking and having the time of their lives...", 'plot_keywords': ['Swimming Pool', 'Female Nudity', 'Impalement', 'Groundskeeper', 'Bikini'], 'country': ['Canada'], 'language': ['English'], 'company': []}
# {'page_id': 168, 'genre': ['Comedy', 'Drama'], 'plot_summary': "When Jack and Sally announce that they're splitting up, this comes as a shock to their best friends Gabe and Judy...", 'plot_keywords': ['Man', 'Human Relationship', 'Trust', 'Fidelity', 'Satirical'], 'country': ['USA'], 'language': ['English'], 'company': ['TriStar Pictures']}
# {'page_id': 170, 'genre': ['Thriller', 'Drama'], 'plot_summary': 'Addison Terrill (Howell), a Dallas attorney, comes home one night to find his wife brutally murdered...', 'plot_keywords': ['Waitress', 'Suicide', 'Street Walker', 'Strangulation', 'Shot In The Chest'], 'country': ['USA'], 'language': ['English', 'Spanish'], 'company': ['Fireside Entertainment']}
# {'page_id': 171, 'genre': ['Comedy', 'Crime'], 'plot_summary': 'A kindergarten director Troshkin is a dead ringer for a criminal nicknamed "Docent" who stole the priceless...', 'plot_keywords': [], 'country': ['Soviet Union'], 'language': ['Russian'], 'company': ['Mosfilm']}
# {'page_id': 172, 'genre': ['Comedy', 'Fantasy', 'Mystery'], 'plot_summary': '', 'plot_keywords': ['Art', 'Epic', 'Steampunk', 'Surreal', 'Ambition'], 'country': ['UK', 'USA'], 'language': ['English'], 'company': ['British Broadcasting Corporation (BBC)']}
# {'page_id': 173, 'genre': ['Comedy', 'Romance'], 'plot_summary': '', 'plot_keywords': ['Cigarette Girl', 'Soviet Union', 'Blindfold', 'Roommate', 'Waiter'], 'country': ['USA'], 'language': ['English'], 'company': ['Metro-Goldwyn-Mayer (MGM)']}
# {'page_id': 174, 'genre': ['Comedy'], 'plot_summary': 'In this mock-documentary, John Cleese narrates a series of sketches on irritation -- types and techniques...', 'plot_keywords': ['Sketch Comedy', 'Fake Documentary', 'Satire', 'Monty Python'], 'country': ['UK'], 'language': ['English'], 'company': ['David Paradine Productions']}
# {'page_id': 176, 'genre': ['Drama', 'Romance'], 'plot_summary': '', 'plot_keywords': ['Dance', 'Dancer', 'Dancing', 'Male Dancer', 'Blonde'], 'country': ['Canada'], 'language': ['English'], 'company': ['Without Word Inc.']}
# {'page_id': 177, 'genre': ['Comedy', 'Documentary'], 'plot_summary': "One of comedian Richard Pryor's live performances (at the Sunset Strip, obviously) caught on film. Pryor talks about most of his standard subjects...", 'plot_keywords': ['Concert Film', 'Stand Up Comedy', 'Vulgarity', 'Racial Slur', 'Person On Fire'], 'country': ['USA'], 'language': ['English'], 'company': ['Columbia Pictures Corporation']}
# {'page_id': 178, 'genre': ['Drama', 'Music'], 'plot_summary': 'At the New York City High School for the Performing Arts, students get specialized training that often leads to success as actors...', 'plot_keywords': ['Coming Of Age', 'Price Of Fame', 'Passion', "Actor's Life", 'Teacher Student Relationship'], 'country': ['USA'], 'language': ['English', 'Spanish', 'French'], 'company': ['Metro-Goldwyn-Mayer (MGM)']}
# {'page_id': 180, 'genre': ['Comedy', 'Crime'], 'plot_summary': '', 'plot_keywords': ['Chase', 'Police', 'Road', 'Sequel', 'Third Part'], 'country': ['USA'], 'language': ['English'], 'company': ['Universal Pictures']}
# {'page_id': 182, 'genre': ['Drama'], 'plot_summary': '', 'plot_keywords': ['Independent Film', 'Based On Play'], 'country': ['USA'], 'language': ['English'], 'company': ['Filmgroup Productions']}
# {'page_id': 183, 'genre': ['Romance', 'Comedy', 'Musical'], 'plot_summary': 'Jo Stockton can only get to Paris to meet with the beatnik founder of "empathicalism" (a idea that implores...', 'plot_keywords': ['Photographer', 'American Abroad', 'Romantic Comedy', 'Beatnik', 'Eiffel Tower Paris'], 'country': ['USA'], 'language': ['English'], 'company': ['Paramount Pictures']}
# {'page_id': 185, 'genre': ['War', 'Drama', 'Action'], 'plot_summary': 'During World War II a special fighting unit is formed combining a crack Canadian outfit and a conglomeration...', 'plot_keywords': ['Germany', 'Nazi', 'WWII', 'Barroom Brawl', 'Canadian Army'], 'country': ['USA'], 'language': ['English'], 'company': ['Wolper Pictures']}
# {'page_id': 187, 'genre': ['Crime', 'Drama', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Aftermath', 'Gasoline', 'Immaturity', 'Tip', 'Gore'], 'country': ['USA'], 'language': ['English'], 'company': ['Live Entertainment']}
# {'page_id': 189, 'genre': ['Action', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Accidental Shooting', 'Arrest', 'Audio Surveillance', 'Bar Scene', 'Bear Trap'], 'country': ['USA'], 'language': ['English'], 'company': ['Curb Entertainment']}
# {'page_id': 190, 'genre': ['Comedy', 'Romance'], 'plot_summary': 'Christoph, cop and self-confident macho, has trouble with his fiance. After a long night he wakes up in the arms of Edgar...', 'plot_keywords': ['Homosexual', 'Homosexuality', 'Human Relationship', 'Coming Out', 'Gay Interest'], 'country': ['Germany'], 'language': ['Russian', 'German'], 'company': ['Bayerischer Rundfunk (BR)']}
# {'page_id': 191, 'genre': ['Documentary'], 'plot_summary': '', 'plot_keywords': [], 'country': ['Canada'], 'language': ['English', 'Hindi'], 'company': ['National Film Board of Canada (NFB)']}
# {'page_id': 194, 'genre': ['Music'], 'plot_summary': "Play - The DVD has eight live tracks recorded on Jools Holland's TV show in England and 10 videos of songs from Moby's album...", 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['Rave New World']}
# {'page_id': 197, 'genre': ['Action', 'War'], 'plot_summary': '', 'plot_keywords': ['Escape', 'Violence', 'Prequel', 'Vietnam', 'Neck Breaking Scene'], 'country': ['USA'], 'language': ['English'], 'company': ['Cannon Films']}
# {'page_id': 198, 'genre': ['Crime', 'Film-Noir', 'Thriller', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Chase', 'Epidemic', 'Illegal Immigrant', 'Carrier', 'Murder'], 'country': ['USA'], 'language': ['Mandarin', 'English'], 'company': ['Twentieth Century-Fox Film Corporation']}
# {'page_id': 199, 'genre': ['Comedy', 'Crime', 'Drama', 'Musical', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Female Crime Boss', 'Directed By Star', 'Irish American', 'Boxer', 'Coney Island'], 'country': ['USA', 'UK', 'Germany'], 'language': ['English'], 'company': ['FilmFour']}
# {'page_id': 201, 'genre': ['Comedy', 'Sci-Fi'], 'plot_summary': '', 'plot_keywords': ['Sequel Mentioned During End Credits', 'Psychiatrist', 'Aviation', 'Bomb', 'Courtroom'], 'country': ['USA'], 'language': ['English'], 'company': ['Paramount Pictures']}
# {'page_id': 203, 'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['No Opening Credits', 'Super Power', 'Invasion', 'Anti Hero', 'Mutant'], 'country': ['USA'], 'language': ['English', 'German'], 'company': ['20th Century Fox']}
# {'page_id': 204, 'genre': ['Animation', 'Horror', 'Sci-Fi', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Anime'], 'country': ['Japan'], 'language': ['Japanese'], 'company': ['Pioneer Entertainment']}
# {'page_id': 207, 'genre': ['Drama'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['Blueprint Entertainment']}
# {'page_id': 209, 'genre': ['Crime', 'Drama', 'Horror', 'Mystery', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Unconventional Romance', 'Quebec City', 'Investigation', 'Murder Investigation', 'Intuition'], 'country': ['USA', 'Canada'], 'language': ['English', 'French'], 'company': ['Warner Bros. Pictures']}
# {'page_id': 210, 'genre': ['Drama', 'Musical', 'Thriller', 'Action', 'Crime'], 'plot_summary': 'Sahil (Bobby Deol) is a rich spoilt brat who dislikes his stepfather, Gov. Jaisingh Sinha (Raj Babbar) ...', 'plot_keywords': ['Stabbed In The Chest', 'Drunk Scene', 'Stepfather Stepson Relationship', 'Jail', 'Murder Trial'], 'country': ['India'], 'language': ['Hindi'], 'company': ['Trimurti Films Pvt. Ltd.']}
# {'page_id': 212, 'genre': ['Drama', 'History'], 'plot_summary': 'Action-packed look at the beginnings of the fall of the Roman Empire. Here is the glory, the greed and grandeur that was Rome...', 'plot_keywords': ['Roman Empire', 'Emperor', 'Massacre', 'Patricide', 'Funeral Pyre'], 'country': ['USA'], 'language': ['English'], 'company': ['Rank Organisation, The']}
# {'page_id': 213, 'genre': ['Documentary'], 'plot_summary': '', 'plot_keywords': ['Electronics', 'Actress', 'Alligator Farm', 'Bayou', 'Cat Lover'], 'country': ['USA'], 'language': ['English', 'Hawaiian'], 'company': ['Blue Mark Productions']}
# {'page_id': 214, 'genre': ['Drama', 'Music'], 'plot_summary': '', 'plot_keywords': ['Louisiana', 'Based On Play', 'Character Name In Title'], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 216, 'genre': ['Documentary'], 'plot_summary': 'A film journey through a universe of female masculinity. A legendary Drag King Night in New York is...', 'plot_keywords': ['Female Full Frontal Nudity', 'Male Full Frontal Nudity', 'Gender', 'Performance', 'Sexuality'], 'country': ['Switzerland', 'USA', 'Germany'], 'language': ['English'], 'company': ['Clockwise Productions']}
# {'page_id': 218, 'genre': ['Documentary'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 222, 'genre': ['Action', 'Fantasy', 'Drama', 'Horror'], 'plot_summary': '', 'plot_keywords': ['Manga', 'Butterfly', 'Demon', 'Exorcism', 'Ghost'], 'country': ['Japan'], 'language': ['Japanese'], 'company': []}
# {'page_id': 223, 'genre': ['Documentary'], 'plot_summary': '', 'plot_keywords': ['Haiti'], 'country': ['USA'], 'language': ['English'], 'company': ['Clinica Estetico Ltd.']}
# {'page_id': 224, 'genre': ['Drama'], 'plot_summary': 'French sailor Querelle arrives in Brest and starts frequenting a strange whorehouse. He discovers that...', 'plot_keywords': ['Gay Lead Character', 'Gay African American', 'Gay Sex Scene', 'Homosexual', 'Melodrama'], 'country': ['West Germany', 'France'], 'language': ['English'], 'company': ['Albatros Filmproduktion']}
# {'page_id': 225, 'genre': ['Drama'], 'plot_summary': 'Is it just another evening at the hugely popular Italian restaurant of proprietor and bookmaker Louis Cropa (Danny Aiello) in New York...', 'plot_keywords': ['Chef', 'Gambling', 'Mafia', 'Restaurant', 'Wig'], 'country': ['USA'], 'language': ['English', 'Italian'], 'company': ['Access Motion Picture Group']}
# {'page_id': 229, 'genre': ['Action', 'Sci-Fi'], 'plot_summary': 'In the future, a man travels to the ends of the earth to find that the perfect woman is always under his nose...', 'plot_keywords': ['Futuristic', 'Road', 'Robot', 'Sex With Robot', 'Independent Film'], 'country': ['USA'], 'language': ['English'], 'company': ['ERP Productions (I)']}
# {'page_id': 231, 'genre': ['Drama'], 'plot_summary': 'While on a train, a teenage boy thinks about his life and the flamboyant aunt whose friendship acted as an emotional shield from his troubled family...', 'plot_keywords': ['Based On Novel', 'Independent Film'], 'country': ['UK'], 'language': ['English'], 'company': ['Academy']}
# {'page_id': 232, 'genre': ['Biography', 'Drama'], 'plot_summary': '', 'plot_keywords': ['1920s', '1930s', 'Historical', 'British Lord', 'British Parliament'], 'country': ['UK'], 'language': ['English'], 'company': ['Southern Television']}
# {'page_id': 234, 'genre': ['Comedy', 'Drama'], 'plot_summary': 'Eight friends in Los Angeles spend their last evening together as they face graduation from high school and the onset of their adult lives...', 'plot_keywords': ['Scavenger Hunt', 'Asian American', 'Korean American', 'Teen', 'Independent Film'], 'country': ['USA'], 'language': ['English', 'Korean'], 'company': []}
# {'page_id': 235, 'genre': ['Comedy', 'Music'], 'plot_summary': '', 'plot_keywords': ['Profanity', 'Urination Scene', 'Culture', 'Masturbation', 'Surreal'], 'country': ['USA'], 'language': ['English'], 'company': ['Marobru Inc.']}
# {'page_id': 240, 'genre': ['Western'], 'plot_summary': '', 'plot_keywords': ['Hold Up', 'Prison', 'Parole', 'Casino', 'Detective'], 'country': ['USA'], 'language': ['English'], 'company': ['20th Century Fox']}
# {'page_id': 243, 'genre': ['Drama'], 'plot_summary': 'During the war between Iran and Iraq, a group of Iranian Kurd musicians set off on an almost impossible mission...', 'plot_keywords': ['Iran', 'Iraq', 'Kurd', 'Oppression', 'Genocide'], 'country': ['Iran'], 'language': ['Persian', 'Kurdish'], 'company': ['Mij Film Co.']}
# {'page_id': 244, 'genre': ['Drama'], 'plot_summary': 'A smart first-year med student takes nothing seriously, except the pursuit of his Gross Anatomy (human dissection) lab partner...', 'plot_keywords': ['Illness', 'Cheating', 'College', 'Medical', 'Human Relationship'], 'country': ['USA'], 'language': ['English'], 'company': ['Hill', 'Rosenman']}
# {'page_id': 245, 'genre': ['Western'], 'plot_summary': 'After Pardon Chato, a mestizo, killed a US marshal in self-defense, a posse pursues him, but as the...', 'plot_keywords': ['Canteen', 'Hit In Head With Rock', 'Beans', 'Pipe Smoking', 'Horse'], 'country': ['USA'], 'language': ['English'], 'company': ['Scimitar Films']}
# {'page_id': 246, 'genre': ['Animation'], 'plot_summary': '', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': []}
# {'page_id': 247, 'genre': ['Drama', 'Romance'], 'plot_summary': 'Character study about Mildred (Gena Rowlands), an elderly woman who has spent her life caring for others...', 'plot_keywords': ['Child', 'Marital Abuse', 'Mother Daughter Relationship', 'Mother Son Relationship', 'Starting Over'], 'country': ['France', 'USA'], 'language': ['English'], 'company': ['Hachette Première']}
# {'page_id': 250, 'genre': ['Documentary', 'Music'], 'plot_summary': '', 'plot_keywords': ['Concert Film', 'Rock Music', '1930s', 'Backstage', 'Beach'], 'country': ['USA'], 'language': ['English'], 'company': ['Swan Song']}
# {'page_id': 251, 'genre': ['Animation', 'Family'], 'plot_summary': "A wonderful adaptation of the Charles Dickens's classic, A Christmas Carol. An overexcited Roo, along with Pooh...", 'plot_keywords': ["Based On Children's Book", 'Bear', 'Disney', 'Donkey', 'Easter'], 'country': ['USA'], 'language': ['English'], 'company': ['Toon City Inc.']}
# {'page_id': 252, 'genre': ['Comedy', 'Romance'], 'plot_summary': "Tess and Sam work on the same newspaper and don't like each other very much. At least the first time...", 'plot_keywords': ['Child', 'Coffee Maker', 'Sports Writer', 'Gender Relations', 'Cooking'], 'country': ['USA'], 'language': ['French', 'Russian', 'English'], 'company': ['Metro-Goldwyn-Mayer (MGM)']}
# {'page_id': 253, 'genre': ['Adventure', 'Mystery', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Biplane', 'Overhead Camera Shot', 'Director Cameo', 'Gun', 'Illinois'], 'country': ['USA'], 'language': ['English'], 'company': ['Metro-Goldwyn-Mayer (MGM)']}
# {'page_id': 254, 'genre': ['Animation', 'Action', 'Drama', 'Fantasy', 'Sci-Fi'], 'plot_summary': '', 'plot_keywords': ['Insanity', 'Sequel To TV Series', 'Anti Hero', 'Mechanic', 'Anime'], 'country': ['Japan'], 'language': ['Japanese'], 'company': ['Gainax']}
# {'page_id': 255, 'genre': ['Drama'], 'plot_summary': 'An African-American prison psychiatrist (Sidney Poitier) finds the boundaries of his professionalism...', 'plot_keywords': ['Psychiatrist', 'Psychoanalysis', 'Independent Film'], 'country': ['USA'], 'language': ['English'], 'company': ['Larcas Productions']}
# {'page_id': 256, 'genre': ['Adventure', 'Animation', 'Comedy', 'Romance', 'Sci-Fi'], 'plot_summary': '', 'plot_keywords': ['Anime'], 'country': ['Japan'], 'language': ['Japanese'], 'company': ['Xebec']}
# {'page_id': 259, 'genre': ['Drama'], 'plot_summary': 'A two character movie, involving a college professor, John, who is confronted by a female student, Carol...', 'plot_keywords': ['Sexual Harassment', 'Adaptation Directed By Original Author', 'Professor', 'Based On Play', 'Independent Film'], 'country': ['UK', 'USA'], 'language': ['English'], 'company': ['Bay Kinescope']}
# {'page_id': 262, 'genre': ['Adventure', 'Drama', 'History', 'War'], 'plot_summary': 'An American Army officer is recruited by the yet to exist Israel to help them form an army. He is disturbed by this sudden appeal to his jewish roots...', 'plot_keywords': ['Historical', 'Based On Book'], 'country': ['USA'], 'language': ['English', 'Hebrew'], 'company': ['Batjac Productions']}
# {'page_id': 264, 'genre': ['Comedy', 'Family', 'Fantasy', 'Adventure'], 'plot_summary': '', 'plot_keywords': ['Parental Relationship', 'Parent Child Relationship', 'Father', 'Father Son Relationship', 'Husband Wife Relationship'], 'country': ['USA'], 'language': ['English'], 'company': ['Columbia Pictures Corporation']}
# {'page_id': 266, 'genre': ['Drama', 'Fantasy'], 'plot_summary': 'Set in a fictional medieval world, this is the story of Asbrey of Westender. Once a great heroic knight...', 'plot_keywords': [], 'country': ['USA'], 'language': ['English'], 'company': ['M.O.B Productions']}
# {'page_id': 267, 'genre': ['Animation', 'Adventure', 'Family', 'Musical', 'Romance'], 'plot_summary': "Now that Frollo is gone, Quasimodo rings the bell with the help of his new friend and Esmeralda's and Phoebus' little son...", 'plot_keywords': ['Sequel', 'Bell Tower', 'Bell', 'Cathedral', 'Circus'], 'country': ['USA'], 'language': ['English'], 'company': ['Walt Disney Home Video']}
# {'page_id': 268, 'genre': ['Crime', 'Drama', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Pigeon', 'Ice Cream', 'Mafia', 'Samurai', 'Katana Sword'], 'country': ['France', 'Germany', 'USA', 'Japan'], 'language': ['English', 'French'], 'company': ['Pandora Filmproduktion']}
# {'page_id': 269, 'genre': ['Animation', 'Family', 'Musical'], 'plot_summary': '', 'plot_keywords': ['Self Sacrifice', 'Sentimental', 'Rescue', 'Love', 'Compassion'], 'country': ['USA'], 'language': ['English'], 'company': ['Hanna-Barbera Productions']}
# {'page_id': 271, 'genre': ['Action', 'Crime', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Kidnap', 'Friend', 'Murder', 'Rape', 'Gang'], 'country': ['Philippines'], 'language': ['Filipino', 'Tagalog'], 'company': ['World Arts Cinema']}
# {'page_id': 272, 'genre': ['Drama', 'Horror', 'Mystery', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Male Nudity', 'Mental Hospital', 'Song', 'Chaos', '1800s'], 'country': ['UK'], 'language': ['English'], 'company': ['Marat Sade Productions']}
# {'page_id': 273, 'genre': ['Drama', 'Film-Noir', 'Thriller'], 'plot_summary': '', 'plot_keywords': ['Paranoid', 'Mistress', 'Psychological Thriller', 'Manhattan', 'Argument'], 'country': ['USA'], 'language': ['English'], 'company': ['Paramount Pictures']}
# {'page_id': 274, 'genre': ['Action', 'Family', 'Adventure', 'Comedy', 'Fantasy', 'Romance'], 'plot_summary': '', 'plot_keywords': ['Animate Car', 'Car Chase', 'Car Stunt', 'Greed', 'Kissing'], 'country': ['USA'], 'language': ['English'], 'company': ['Walt Disney Pictures']}
# {'page_id': 278, 'genre': ['Documentary'], 'plot_summary': '', 'plot_keywords': [], 'country': ['Brazil', 'France', 'Belgium'], 'language': ['Portuguese'], 'company': ['A.F. Cinema e Vídeo']}
# {'page_id': 281, 'genre': ['Comedy', 'Drama'], 'plot_summary': '', 'plot_keywords': ['Struggle', 'Social Adjustment', 'Quirky', 'Parent', 'Gambling'], 'country': ['USA'], 'language': ['English'], 'company': ['Imagine Entertainment']}
# {'page_id': 283, 'genre': ['Animation', 'Short', 'Family', 'Comedy', 'Musical'], 'plot_summary': '', 'plot_keywords': ['Anthology', 'Disney Animated Feature', 'Donald Duck', 'Joe Carioca', 'Part Live Action'], 'country': ['USA'], 'language': ['English', 'Portuguese'], 'company': ['Walt Disney Pictures']}
# {'page_id': 284, 'genre': ['Crime', 'Drama', 'Thriller'], 'plot_summary': 'Ocho is accidentally captured by a drug trafficking cartel who use Chinese women to smuggle drugs into Japan by hiding it in their vaginas...', 'plot_keywords': ['Dark Heroine', 'Breasts', 'Beautiful Woman', 'Sensuality', 'Female Nudity'], 'country': ['Japan'], 'language': ['Japanese'], 'company': ['Toei Company']}
# {'page_id': 286, 'genre': ['Drama', 'Thriller'], 'plot_summary': 'A famous psychiatrist (Ty Adams) takes on the job of trying to cure patients at the Sedah State Hospital...', 'plot_keywords': ['Dead Child', 'Dead Wife', 'Devil', 'Director', 'Guilty Conscience'], 'country': ['USA'], 'language': ['English'], 'company': ['Humble Journey Films']}
# {'page_id': 287, 'genre': ['Drama'], 'plot_summary': 'Desmond Doyle is devastated when his wife abandons their family on the day after Christmas. His unemployment...', 'plot_keywords': ['Loss Of Father', 'Trespassing', 'Loss Of Grandfather', 'Christmas Eve', 'Child Abuse'], 'country': ['Germany', 'Ireland', 'USA', 'UK'], 'language': ['English'], 'company': ['CineEvelyn']}
# {'page_id': 288, 'genre': ['Action', 'Sci-Fi'], 'plot_summary': '', 'plot_keywords': ['Post Apocalyptic'], 'country': ['USA'], 'language': ['English'], 'company': ['Nu Image Films']}
# {'page_id': 290, 'genre': ['Drama'], 'plot_summary': '', 'plot_keywords': ['Surreal', 'Female Frontal Nudity', 'Child Nudity', 'Military', 'Male Frontal Nudity'], 'country': ['Soviet Union'], 'language': ['Russian'], 'company': ['Gorky Film Studios']}
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_27380\1103446073.py:16: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   result = es.search(index='web_extended_info', body=query)
